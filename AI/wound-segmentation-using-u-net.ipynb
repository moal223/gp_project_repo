# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from tqdm import tqdm
import cv2
import itertools

import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K

from sklearn.metrics import confusion_matrix

# Set matplotlib to display plots inline in Jupyter notebooks
# %matplotlib inline

# %%
import os
from glob import glob

# Define paths for training and testing data
TRAIN_IMAGE_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/train_images'
TRAIN_MASK_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/train_masks'
TEST_IMAGE_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images'
TEST_MASK_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_masks'
CORRESPONDENCE_TABLE_PATH = '/kaggle/input/wound-segmentation-images/data_wound_seg/correspondence_table.xlsx'

def get_file_paths(image_dir, mask_dir, file_extension='*.png'):
    """
    Retrieves sorted lists of image and mask file paths from the specified directories.

    Args:
        image_dir (str): Directory containing image files.
        mask_dir (str): Directory containing mask files.
        file_extension (str): File extension to filter files (default is '*.png').

    Returns:
        tuple: Two lists containing sorted image paths and mask paths.
    """
    images = sorted(glob(os.path.join(image_dir, file_extension)))
    masks = sorted(glob(os.path.join(mask_dir, file_extension)))
    return images, masks

def validate_dataset(images, masks, dataset_name):
    """
    Validates that the number of images and masks match and prints the count.

    Args:
        images (list): List of image file paths.
        masks (list): List of mask file paths.
        dataset_name (str): Name of the dataset (e.g., 'training', 'testing').

    Raises:
        ValueError: If the number of images and masks do not match.
    """
    if len(images) != len(masks):
        raise ValueError(f"Mismatch in {dataset_name} dataset: {len(images)} images vs {len(masks)} masks.")
    print(f"Number of {dataset_name} images: {len(images)}")
    print(f"Number of {dataset_name} masks: {len(masks)}")

# Get file paths for training and testing datasets
train_images, train_masks = get_file_paths(TRAIN_IMAGE_DIR, TRAIN_MASK_DIR)
test_images, test_masks = get_file_paths(TEST_IMAGE_DIR, TEST_MASK_DIR)

# Validate and print dataset sizes
validate_dataset(train_images, train_masks, 'training')
validate_dataset(test_images, test_masks, 'testing')
# Out:
# Number of training images: 2208
# Number of training masks: 2208
# Number of testing images: 552
# Number of testing masks: 552

# %%
import matplotlib.pyplot as plt
import cv2

def display_samples(images, masks, num_samples=5):
    """
    Displays a sample of images and their corresponding masks side by side.

    Args:
        images (list): List of paths to image files.
        masks (list): List of paths to mask files.
        num_samples (int): Number of samples to display (default is 5).

    Raises:
        ValueError: If the number of images and masks do not match.
    """
    if len(images) != len(masks):
        raise ValueError("The number of images and masks must be the same.")

    # Set up the figure for visualization
    plt.figure(figsize=(12, num_samples * 4))

    for i in range(num_samples):
        # Load and preprocess the image
        img = cv2.imread(images[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct display

        # Load the mask in grayscale
        mask = cv2.imread(masks[i], cv2.IMREAD_GRAYSCALE)

        # Display the image
        plt.subplot(num_samples, 2, 2 * i + 1)
        plt.imshow(img)
        plt.title(f'Image {i + 1}')
        plt.axis('off')

        # Display the corresponding mask
        plt.subplot(num_samples, 2, 2 * i + 2)
        plt.imshow(mask, cmap='gray')
        plt.title(f'Mask {i + 1}')
        plt.axis('off')

    # Adjust layout for better visualization
    plt.tight_layout()
    plt.show()

# Example usage: Display 3 samples from the training set
display_samples(train_images, train_masks, num_samples=3)

# %%
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence

# Constants for configuration
IMG_HEIGHT = 256  # Target image height
IMG_WIDTH = 256   # Target image width
BATCH_SIZE = 16   # Batch size for training
NORMALIZE_FACTOR = 255.0  # Normalization factor for pixel values

class DataGenerator(Sequence):
    """
    Custom data generator for loading and augmenting images and masks in batches.

    Args:
        image_filenames (list): List of paths to image files.
        mask_filenames (list): List of paths to mask files.
        batch_size (int): Number of samples per batch.
        img_height (int): Target height for resizing images and masks.
        img_width (int): Target width for resizing images and masks.
        augment (bool): Whether to apply data augmentation (default is False).
    """

    def __init__(self, image_filenames, mask_filenames, batch_size, img_height, img_width, augment=False):
        self.image_filenames = image_filenames
        self.mask_filenames = mask_filenames
        self.batch_size = batch_size
        self.img_height = img_height
        self.img_width = img_width
        self.augment = augment

    def __len__(self):
        """Returns the number of batches per epoch."""
        return int(np.ceil(len(self.image_filenames) / self.batch_size))

    def __getitem__(self, idx):
        """Generates one batch of data."""
        batch_x = self.image_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.mask_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]

        images, masks = [], []
        for img_path, mask_path in zip(batch_x, batch_y):
            img = self._load_and_preprocess_image(img_path)
            mask = self._load_and_preprocess_mask(mask_path)

            if self.augment:
                img, mask = self._apply_augmentation(img, mask)

            images.append(img)
            masks.append(mask)

        return np.array(images), np.array(masks)

    def _load_and_preprocess_image(self, img_path):
        """Loads and preprocesses an image."""
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
        img = cv2.resize(img, (self.img_width, self.img_height))  # Resize
        img = img / NORMALIZE_FACTOR  # Normalize to [0, 1]
        img = img.astype(np.float32)  # Cast to float32
        return img

    def _load_and_preprocess_mask(self, mask_path):
        """Loads and preprocesses a mask."""
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
        mask = cv2.resize(mask, (self.img_width, self.img_height))  # Resize
        mask = np.expand_dims(mask, axis=-1)  # Add channel dimension
        mask = mask / NORMALIZE_FACTOR  # Normalize to [0, 1]
        mask = mask.astype(np.float32)  # Cast to float32
        return mask

    def _apply_augmentation(self, img, mask):
        """Applies random augmentation to an image and its mask."""
        # Random horizontal flip
        if np.random.rand() > 0.5:
            img = np.fliplr(img)
            mask = np.fliplr(mask)

        # Random vertical flip
        if np.random.rand() > 0.5:
            img = np.flipud(img)
            mask = np.flipud(mask)

        # Random rotation
        angle = np.random.randint(-15, 15)
        M = cv2.getRotationMatrix2D((self.img_width / 2, self.img_height / 2), angle, 1)
        img = cv2.warpAffine(img, M, (self.img_width, self.img_height)).astype(np.float32)
        mask = cv2.warpAffine(mask, M, (self.img_width, self.img_height)).astype(np.float32)

        return img, mask

# Create data generators
train_generator = DataGenerator(train_images, train_masks, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH, augment=True)
test_generator = DataGenerator(test_images, test_masks, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH)

# %%
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence

class DataGenerator(Sequence):
    """
    Custom data generator for loading and augmenting images and masks in batches.

    Args:
        image_filenames (list): List of paths to image files.
        mask_filenames (list): List of paths to mask files.
        batch_size (int): Number of samples per batch.
        img_height (int): Target height for resizing images and masks.
        img_width (int): Target width for resizing images and masks.
        augment (bool): Whether to apply data augmentation (default is False).
    """

    def __init__(self, image_filenames, mask_filenames, batch_size, img_height, img_width, augment=False):
        self.image_filenames = image_filenames
        self.mask_filenames = mask_filenames
        self.batch_size = batch_size
        self.img_height = img_height
        self.img_width = img_width
        self.augment = augment

    def __len__(self):
        """Returns the number of batches per epoch."""
        return int(np.ceil(len(self.image_filenames) / self.batch_size))

    def __getitem__(self, idx):
        """Generates one batch of data."""
        batch_x = self.image_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.mask_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]

        images, masks = [], []
        for img_path, mask_path in zip(batch_x, batch_y):
            img = self._load_and_preprocess_image(img_path)
            mask = self._load_and_preprocess_mask(mask_path)

            if self.augment:
                img, mask = self._apply_augmentation(img, mask)

            images.append(img)
            masks.append(mask)

        return np.array(images), np.array(masks)

    def _load_and_preprocess_image(self, img_path):
        """Loads and preprocesses an image."""
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
        img = cv2.resize(img, (self.img_width, self.img_height))  # Resize
        img = img / 255.0  # Normalize to [0, 1]
        return img

    def _load_and_preprocess_mask(self, mask_path):
        """Loads and preprocesses a mask."""
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
        mask = cv2.resize(mask, (self.img_width, self.img_height))  # Resize
        mask = np.expand_dims(mask, axis=-1)  # Add channel dimension
        mask = mask / 255.0  # Normalize to [0, 1]
        return mask

    def _apply_augmentation(self, img, mask):
        """Applies random augmentation to an image and its mask."""
        # Random horizontal flip
        if np.random.rand() > 0.5:
            img = np.fliplr(img)
            mask = np.fliplr(mask)

        # Random vertical flip
        if np.random.rand() > 0.5:
            img = np.flipud(img)
            mask = np.flipud(mask)

        # Random rotation
        angle = np.random.randint(-15, 15)
        M = cv2.getRotationMatrix2D((self.img_width / 2, self.img_height / 2), angle, 1)
        img = cv2.warpAffine(img, M, (self.img_width, self.img_height))
        mask = cv2.warpAffine(mask, M, (self.img_width, self.img_height))

        return img, mask

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model

def unet_model(input_size=(256, 256, 3)):
    """
    Defines a U-Net model for image segmentation.

    Args:
        input_size (tuple): Input image dimensions (height, width, channels). Default is (256, 256, 3).

    Returns:
        model (tf.keras.Model): A U-Net model.
    """
    inputs = Input(input_size)

    # Encoder (Downsampling Path)
    def encoder_block(input_tensor, filters, dropout_rate):
        """Creates an encoder block with two convolutional layers, batch normalization, and dropout."""
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(input_tensor)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rate)(x)
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        p = MaxPooling2D((2, 2))(x)
        return x, p

    c1, p1 = encoder_block(inputs, 64, 0.1)
    c2, p2 = encoder_block(p1, 128, 0.1)
    c3, p3 = encoder_block(p2, 256, 0.2)
    c4, p4 = encoder_block(p3, 512, 0.2)

    # Bridge
    bridge = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    bridge = BatchNormalization()(bridge)
    bridge = Dropout(0.3)(bridge)
    bridge = Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)

    # Decoder (Upsampling Path)
    def decoder_block(input_tensor, skip_tensor, filters, dropout_rate):
        """Creates a decoder block with upsampling, concatenation, and two convolutional layers."""
        x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
        x = concatenate([x, skip_tensor])
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rate)(x)
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        return x

    d1 = decoder_block(bridge, c4, 512, 0.2)
    d2 = decoder_block(d1, c3, 256, 0.2)
    d3 = decoder_block(d2, c2, 128, 0.1)
    d4 = decoder_block(d3, c1, 64, 0.1)

    # Output Layer
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(d4)

    # Create the model
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# Instantiate the model
model = unet_model()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 128, 128, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 64, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 32, 32, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 32, 32, 512)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 512)    │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 16, 16, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 16, 16, 1024)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 1024)   │      9,438,208 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 512)    │      2,097,664 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 32, 32, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 32, 32, 512)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 256)    │        524,544 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 64, 64, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 64, 64, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 128)  │        131,200 │ conv2d_13[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 128)  │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 128, 128, 128)  │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128, 128, 128)  │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 64)   │         32,832 │ conv2d_15[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 256, 256, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 256, 256, 64)   │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 256, 256, 64)   │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ dropout_8[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ conv2d_17[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,043,521 (118.42 MB)
#  Trainable params: 31,037,633 (118.40 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1):
    """
    Computes the Dice Coefficient, a metric for evaluating segmentation performance.

    Args:
        y_true (tensor): Ground truth labels.
        y_pred (tensor): Predicted labels.
        smooth (float): Smoothing factor to avoid division by zero. Default is 1.

    Returns:
        dice (tensor): Dice Coefficient score.
    """
    # Flatten and cast tensors to float32
    y_true_f = K.flatten(K.cast(y_true, 'float32'))
    y_pred_f = K.flatten(K.cast(y_pred, 'float32'))

    # Compute intersection and Dice Coefficient
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def iou_metric(y_true, y_pred, smooth=1):
    """
    Computes the Intersection over Union (IoU), a metric for evaluating segmentation performance.

    Args:
        y_true (tensor): Ground truth labels.
        y_pred (tensor): Predicted labels.
        smooth (float): Smoothing factor to avoid division by zero. Default is 1.

    Returns:
        iou (tensor): IoU score.
    """
    # Flatten and cast tensors to float32
    y_true_f = K.flatten(K.cast(y_true, 'float32'))
    y_pred_f = K.flatten(K.cast(y_pred, 'float32'))

    # Compute intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection

    # Compute IoU
    iou = (intersection + smooth) / (union + smooth)
    return iou

# %%
from tensorflow.keras.optimizers import Adam

# Compile the model with specified optimizer, loss function, and metrics
model.compile(
    optimizer=Adam(learning_rate=1e-4),  # Use Adam optimizer with a learning rate of 1e-4
    loss='binary_crossentropy',          # Use binary cross-entropy as the loss function
    metrics=[
        'accuracy',                      # Track accuracy during training
        dice_coefficient,                # Use Dice Coefficient as a custom metric
        iou_metric                       # Use Intersection over Union (IoU) as a custom metric
    ]
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Define callbacks for training
def get_callbacks():
    """
    Creates and returns a list of callbacks for model training.

    Returns:
        list: A list of callbacks including ModelCheckpoint, EarlyStopping, and ReduceLROnPlateau.
    """
    # Save the best model based on validation loss
    checkpoint = ModelCheckpoint(
        'unet_wound_segmentation_best.keras',  # Save model with .keras extension
        monitor='val_loss',                    # Monitor validation loss
        save_best_only=True,                   # Save only the best model
        verbose=1,                             # Log progress
        mode='min'                             # Minimize validation loss
    )

    # Stop training early if validation loss does not improve
    earlystop = EarlyStopping(
        monitor='val_loss',                    # Monitor validation loss
        patience=15,                           # Wait for 15 epochs without improvement
        verbose=1,                             # Log progress
        restore_best_weights=True              # Restore the best model weights
    )

    # Reduce learning rate if validation loss plateaus
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',                    # Monitor validation loss
        factor=0.5,                            # Reduce learning rate by 50%
        patience=7,                            # Wait for 7 epochs without improvement
        verbose=1,                             # Log progress
        mode='min',                            # Minimize validation loss
        min_lr=1e-6                            # Minimum learning rate
    )

    return [checkpoint, earlystop, reduce_lr]

# Compile the model
def compile_model(model):
    """
    Compiles the model with Adam optimizer, binary cross-entropy loss, and custom metrics.

    Args:
        model (tf.keras.Model): The model to compile.

    Returns:
        None
    """
    model.compile(
        optimizer=Adam(learning_rate=1e-4),    # Use Adam optimizer with a learning rate of 1e-4
        loss='binary_crossentropy',            # Use binary cross-entropy loss
        metrics=['accuracy', dice_coefficient, iou_metric]  # Track accuracy, Dice Coefficient, and IoU
    )

# Train the model
def train_model(model, train_generator, test_generator, epochs=100):
    """
    Trains the model using the provided data generators and callbacks.

    Args:
        model (tf.keras.Model): The model to train.
        train_generator (DataGenerator): Training data generator.
        test_generator (DataGenerator): Validation data generator.
        epochs (int): Number of training epochs. Default is 100.

    Returns:
        history: Training history object.
    """
    callbacks_list = get_callbacks()  # Get the list of callbacks

    history = model.fit(
        train_generator,
        validation_data=test_generator,
        epochs=epochs,                # Number of training epochs
        callbacks=callbacks_list,     # Use defined callbacks
        verbose=1                     # Log progress
    )
    return history

# Example usage
compile_model(model)  # Compile the model
history = train_model(model, train_generator, test_generator, epochs=100)  # Train the model
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - accuracy: 0.7750 - dice_coefficient: 0.1370 - iou_metric: 0.0751 - loss: 0.4363
# Epoch 1: val_loss improved from inf to 0.11360, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 242s 1s/step - accuracy: 0.7759 - dice_coefficient: 0.1372 - iou_metric: 0.0752 - loss: 0.4349 - val_accuracy: 0.9860 - val_dice_coefficient: 0.0257 - val_iou_metric: 0.0130 - val_loss: 0.1136 - learning_rate: 1.0000e-04
# Epoch 2/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.9612 - dice_coefficient: 0.2877 - iou_metric: 0.1718 - loss: 0.1107
# Epoch 2: val_loss improved from 0.11360 to 0.06858, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 865ms/step - accuracy: 0.9612 - dice_coefficient: 0.2877 - iou_metric: 0.1719 - loss: 0.1108 - val_accuracy: 0.9860 - val_dice_coefficient: 0.0343 - val_iou_metric: 0.0175 - val_loss: 0.0686 - learning_rate: 1.0000e-04
# Epoch 3/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9576 - dice_coefficient: 0.3263 - iou_metric: 0.2008 - loss: 0.1105
# Epoch 3: val_loss improved from 0.06858 to 0.05445, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 867ms/step - accuracy: 0.9576 - dice_coefficient: 0.3264 - iou_metric: 0.2009 - loss: 0.1105 - val_accuracy: 0.9860 - val_dice_coefficient: 0.0586 - val_iou_metric: 0.0303 - val_loss: 0.0545 - learning_rate: 1.0000e-04
# Epoch 4/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9616 - dice_coefficient: 0.4390 - iou_metric: 0.2885 - loss: 0.0902
# Epoch 4: val_loss did not improve from 0.05445
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 858ms/step - accuracy: 0.9616 - dice_coefficient: 0.4389 - iou_metric: 0.2884 - loss: 0.0902 - val_accuracy: 0.9871 - val_dice_coefficient: 0.1697 - val_iou_metric: 0.0947 - val_loss: 0.0589 - learning_rate: 1.0000e-04
# Epoch 5/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.9672 - dice_coefficient: 0.4744 - iou_metric: 0.3179 - loss: 0.0789
# Epoch 5: val_loss improved from 0.05445 to 0.02437, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 123s 877ms/step - accuracy: 0.9672 - dice_coefficient: 0.4744 - iou_metric: 0.3179 - loss: 0.0789 - val_accuracy: 0.9909 - val_dice_coefficient: 0.4624 - val_iou_metric: 0.3043 - val_loss: 0.0244 - learning_rate: 1.0000e-04
# Epoch 6/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9710 - dice_coefficient: 0.5251 - iou_metric: 0.3641 - loss: 0.0670
# Epoch 6: val_loss improved from 0.02437 to 0.02415, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 871ms/step - accuracy: 0.9710 - dice_coefficient: 0.5251 - iou_metric: 0.3642 - loss: 0.0670 - val_accuracy: 0.9909 - val_dice_coefficient: 0.4825 - val_iou_metric: 0.3236 - val_loss: 0.0241 - learning_rate: 1.0000e-04
# Epoch 7/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9713 - dice_coefficient: 0.5646 - iou_metric: 0.3991 - loss: 0.0646
# Epoch 7: val_loss improved from 0.02415 to 0.02289, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 874ms/step - accuracy: 0.9713 - dice_coefficient: 0.5646 - iou_metric: 0.3992 - loss: 0.0646 - val_accuracy: 0.9912 - val_dice_coefficient: 0.4889 - val_iou_metric: 0.3275 - val_loss: 0.0229 - learning_rate: 1.0000e-04
# Epoch 8/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9721 - dice_coefficient: 0.5955 - iou_metric: 0.4328 - loss: 0.0611
# Epoch 8: val_loss did not improve from 0.02289
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9721 - dice_coefficient: 0.5954 - iou_metric: 0.4327 - loss: 0.0611 - val_accuracy: 0.9908 - val_dice_coefficient: 0.4725 - val_iou_metric: 0.3134 - val_loss: 0.0246 - learning_rate: 1.0000e-04
# Epoch 9/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9754 - dice_coefficient: 0.6194 - iou_metric: 0.4555 - loss: 0.0533
# Epoch 9: val_loss improved from 0.02289 to 0.01792, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 873ms/step - accuracy: 0.9754 - dice_coefficient: 0.6194 - iou_metric: 0.4555 - loss: 0.0533 - val_accuracy: 0.9932 - val_dice_coefficient: 0.5753 - val_iou_metric: 0.4071 - val_loss: 0.0179 - learning_rate: 1.0000e-04
# Epoch 10/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9768 - dice_coefficient: 0.6411 - iou_metric: 0.4783 - loss: 0.0498
# Epoch 10: val_loss did not improve from 0.01792
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9768 - dice_coefficient: 0.6410 - iou_metric: 0.4783 - loss: 0.0498 - val_accuracy: 0.9911 - val_dice_coefficient: 0.5322 - val_iou_metric: 0.3662 - val_loss: 0.0246 - learning_rate: 1.0000e-04
# Epoch 11/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9797 - dice_coefficient: 0.6399 - iou_metric: 0.4777 - loss: 0.0441
# Epoch 11: val_loss did not improve from 0.01792
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 859ms/step - accuracy: 0.9797 - dice_coefficient: 0.6400 - iou_metric: 0.4778 - loss: 0.0441 - val_accuracy: 0.9926 - val_dice_coefficient: 0.5713 - val_iou_metric: 0.4039 - val_loss: 0.0213 - learning_rate: 1.0000e-04
# Epoch 12/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.9774 - dice_coefficient: 0.6740 - iou_metric: 0.5169 - loss: 0.0461
# Epoch 12: val_loss did not improve from 0.01792
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 862ms/step - accuracy: 0.9774 - dice_coefficient: 0.6740 - iou_metric: 0.5169 - loss: 0.0461 - val_accuracy: 0.9922 - val_dice_coefficient: 0.6568 - val_iou_metric: 0.4919 - val_loss: 0.0182 - learning_rate: 1.0000e-04
# Epoch 13/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9797 - dice_coefficient: 0.6862 - iou_metric: 0.5303 - loss: 0.0418
# Epoch 13: val_loss did not improve from 0.01792
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 860ms/step - accuracy: 0.9797 - dice_coefficient: 0.6862 - iou_metric: 0.5303 - loss: 0.0418 - val_accuracy: 0.9927 - val_dice_coefficient: 0.6492 - val_iou_metric: 0.4863 - val_loss: 0.0190 - learning_rate: 1.0000e-04
# Epoch 14/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9783 - dice_coefficient: 0.6784 - iou_metric: 0.5222 - loss: 0.0459
# Epoch 14: val_loss improved from 0.01792 to 0.01742, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 873ms/step - accuracy: 0.9783 - dice_coefficient: 0.6785 - iou_metric: 0.5224 - loss: 0.0459 - val_accuracy: 0.9932 - val_dice_coefficient: 0.6481 - val_iou_metric: 0.4839 - val_loss: 0.0174 - learning_rate: 1.0000e-04
# Epoch 15/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9787 - dice_coefficient: 0.7061 - iou_metric: 0.5528 - loss: 0.0433
# Epoch 15: val_loss improved from 0.01742 to 0.01383, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 873ms/step - accuracy: 0.9787 - dice_coefficient: 0.7061 - iou_metric: 0.5529 - loss: 0.0432 - val_accuracy: 0.9943 - val_dice_coefficient: 0.7008 - val_iou_metric: 0.5428 - val_loss: 0.0138 - learning_rate: 1.0000e-04
# Epoch 16/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9818 - dice_coefficient: 0.7124 - iou_metric: 0.5609 - loss: 0.0365
# Epoch 16: val_loss improved from 0.01383 to 0.01346, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 872ms/step - accuracy: 0.9818 - dice_coefficient: 0.7125 - iou_metric: 0.5610 - loss: 0.0365 - val_accuracy: 0.9943 - val_dice_coefficient: 0.7148 - val_iou_metric: 0.5592 - val_loss: 0.0135 - learning_rate: 1.0000e-04
# Epoch 17/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9822 - dice_coefficient: 0.7551 - iou_metric: 0.6146 - loss: 0.0338
# Epoch 17: val_loss did not improve from 0.01346
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 858ms/step - accuracy: 0.9822 - dice_coefficient: 0.7549 - iou_metric: 0.6144 - loss: 0.0338 - val_accuracy: 0.9938 - val_dice_coefficient: 0.7268 - val_iou_metric: 0.5739 - val_loss: 0.0151 - learning_rate: 1.0000e-04
# Epoch 18/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.9806 - dice_coefficient: 0.7383 - iou_metric: 0.5914 - loss: 0.0389
# Epoch 18: val_loss did not improve from 0.01346
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 862ms/step - accuracy: 0.9806 - dice_coefficient: 0.7383 - iou_metric: 0.5914 - loss: 0.0388 - val_accuracy: 0.9921 - val_dice_coefficient: 0.6906 - val_iou_metric: 0.5306 - val_loss: 0.0184 - learning_rate: 1.0000e-04
# Epoch 19/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9830 - dice_coefficient: 0.7353 - iou_metric: 0.5891 - loss: 0.0332
# Epoch 19: val_loss did not improve from 0.01346
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 859ms/step - accuracy: 0.9830 - dice_coefficient: 0.7353 - iou_metric: 0.5892 - loss: 0.0332 - val_accuracy: 0.9944 - val_dice_coefficient: 0.7048 - val_iou_metric: 0.5471 - val_loss: 0.0138 - learning_rate: 1.0000e-04
# Epoch 20/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9840 - dice_coefficient: 0.7594 - iou_metric: 0.6183 - loss: 0.0302
# Epoch 20: val_loss improved from 0.01346 to 0.01258, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 875ms/step - accuracy: 0.9840 - dice_coefficient: 0.7594 - iou_metric: 0.6183 - loss: 0.0302 - val_accuracy: 0.9947 - val_dice_coefficient: 0.7225 - val_iou_metric: 0.5687 - val_loss: 0.0126 - learning_rate: 1.0000e-04
# Epoch 21/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9847 - dice_coefficient: 0.7707 - iou_metric: 0.6322 - loss: 0.0283
# Epoch 21: val_loss did not improve from 0.01258
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 858ms/step - accuracy: 0.9847 - dice_coefficient: 0.7707 - iou_metric: 0.6322 - loss: 0.0283 - val_accuracy: 0.9946 - val_dice_coefficient: 0.7048 - val_iou_metric: 0.5477 - val_loss: 0.0129 - learning_rate: 1.0000e-04
# Epoch 22/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9817 - dice_coefficient: 0.7268 - iou_metric: 0.5802 - loss: 0.0360
# Epoch 22: val_loss did not improve from 0.01258
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9817 - dice_coefficient: 0.7269 - iou_metric: 0.5803 - loss: 0.0360 - val_accuracy: 0.9937 - val_dice_coefficient: 0.7067 - val_iou_metric: 0.5499 - val_loss: 0.0149 - learning_rate: 1.0000e-04
# Epoch 23/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9831 - dice_coefficient: 0.7629 - iou_metric: 0.6220 - loss: 0.0310
# Epoch 23: val_loss improved from 0.01258 to 0.01173, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 874ms/step - accuracy: 0.9831 - dice_coefficient: 0.7629 - iou_metric: 0.6221 - loss: 0.0310 - val_accuracy: 0.9951 - val_dice_coefficient: 0.7328 - val_iou_metric: 0.5807 - val_loss: 0.0117 - learning_rate: 1.0000e-04
# Epoch 24/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9855 - dice_coefficient: 0.7711 - iou_metric: 0.6333 - loss: 0.0262
# Epoch 24: val_loss did not improve from 0.01173
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9855 - dice_coefficient: 0.7712 - iou_metric: 0.6334 - loss: 0.0262 - val_accuracy: 0.9945 - val_dice_coefficient: 0.7243 - val_iou_metric: 0.5704 - val_loss: 0.0130 - learning_rate: 1.0000e-04
# Epoch 25/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9843 - dice_coefficient: 0.7869 - iou_metric: 0.6547 - loss: 0.0282
# Epoch 25: val_loss did not improve from 0.01173
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 859ms/step - accuracy: 0.9843 - dice_coefficient: 0.7868 - iou_metric: 0.6546 - loss: 0.0282 - val_accuracy: 0.9947 - val_dice_coefficient: 0.7185 - val_iou_metric: 0.5636 - val_loss: 0.0125 - learning_rate: 1.0000e-04
# Epoch 26/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9850 - dice_coefficient: 0.7838 - iou_metric: 0.6499 - loss: 0.0267
# Epoch 26: val_loss did not improve from 0.01173
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9850 - dice_coefficient: 0.7839 - iou_metric: 0.6499 - loss: 0.0267 - val_accuracy: 0.9948 - val_dice_coefficient: 0.7343 - val_iou_metric: 0.5836 - val_loss: 0.0120 - learning_rate: 1.0000e-04
# Epoch 27/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9843 - dice_coefficient: 0.7891 - iou_metric: 0.6571 - loss: 0.0285
# Epoch 27: val_loss did not improve from 0.01173
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 859ms/step - accuracy: 0.9843 - dice_coefficient: 0.7890 - iou_metric: 0.6569 - loss: 0.0285 - val_accuracy: 0.9944 - val_dice_coefficient: 0.7551 - val_iou_metric: 0.6091 - val_loss: 0.0127 - learning_rate: 1.0000e-04
# Epoch 28/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9860 - dice_coefficient: 0.7972 - iou_metric: 0.6673 - loss: 0.0246
# Epoch 28: val_loss improved from 0.01173 to 0.01128, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 871ms/step - accuracy: 0.9860 - dice_coefficient: 0.7972 - iou_metric: 0.6673 - loss: 0.0246 - val_accuracy: 0.9951 - val_dice_coefficient: 0.7610 - val_iou_metric: 0.6167 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 29/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9870 - dice_coefficient: 0.7971 - iou_metric: 0.6674 - loss: 0.0223
# Epoch 29: val_loss did not improve from 0.01128
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9870 - dice_coefficient: 0.7971 - iou_metric: 0.6674 - loss: 0.0224 - val_accuracy: 0.9950 - val_dice_coefficient: 0.7743 - val_iou_metric: 0.6344 - val_loss: 0.0116 - learning_rate: 1.0000e-04
# Epoch 30/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9862 - dice_coefficient: 0.8146 - iou_metric: 0.6923 - loss: 0.0231
# Epoch 30: val_loss did not improve from 0.01128
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9862 - dice_coefficient: 0.8145 - iou_metric: 0.6922 - loss: 0.0231 - val_accuracy: 0.9949 - val_dice_coefficient: 0.7232 - val_iou_metric: 0.5701 - val_loss: 0.0123 - learning_rate: 1.0000e-04
# Epoch 31/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9851 - dice_coefficient: 0.7486 - iou_metric: 0.6066 - loss: 0.0282
# Epoch 31: val_loss did not improve from 0.01128
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9851 - dice_coefficient: 0.7488 - iou_metric: 0.6069 - loss: 0.0282 - val_accuracy: 0.9945 - val_dice_coefficient: 0.7179 - val_iou_metric: 0.5630 - val_loss: 0.0126 - learning_rate: 1.0000e-04
# Epoch 32/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9866 - dice_coefficient: 0.7894 - iou_metric: 0.6575 - loss: 0.0232
# Epoch 32: val_loss improved from 0.01128 to 0.01081, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 872ms/step - accuracy: 0.9865 - dice_coefficient: 0.7895 - iou_metric: 0.6577 - loss: 0.0232 - val_accuracy: 0.9952 - val_dice_coefficient: 0.7708 - val_iou_metric: 0.6296 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 33/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9874 - dice_coefficient: 0.8085 - iou_metric: 0.6830 - loss: 0.0208
# Epoch 33: val_loss did not improve from 0.01081
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 858ms/step - accuracy: 0.9874 - dice_coefficient: 0.8086 - iou_metric: 0.6831 - loss: 0.0208 - val_accuracy: 0.9945 - val_dice_coefficient: 0.7658 - val_iou_metric: 0.6231 - val_loss: 0.0129 - learning_rate: 1.0000e-04
# Epoch 34/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9873 - dice_coefficient: 0.8270 - iou_metric: 0.7095 - loss: 0.0204
# Epoch 34: val_loss improved from 0.01081 to 0.01079, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 872ms/step - accuracy: 0.9873 - dice_coefficient: 0.8269 - iou_metric: 0.7094 - loss: 0.0204 - val_accuracy: 0.9951 - val_dice_coefficient: 0.7701 - val_iou_metric: 0.6283 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 35/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9862 - dice_coefficient: 0.8353 - iou_metric: 0.7219 - loss: 0.0224
# Epoch 35: val_loss did not improve from 0.01079
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 856ms/step - accuracy: 0.9862 - dice_coefficient: 0.8353 - iou_metric: 0.7218 - loss: 0.0224 - val_accuracy: 0.9947 - val_dice_coefficient: 0.7544 - val_iou_metric: 0.6084 - val_loss: 0.0116 - learning_rate: 1.0000e-04
# Epoch 36/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9874 - dice_coefficient: 0.8190 - iou_metric: 0.6982 - loss: 0.0204
# Epoch 36: val_loss did not improve from 0.01079
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 861ms/step - accuracy: 0.9874 - dice_coefficient: 0.8190 - iou_metric: 0.6982 - loss: 0.0204 - val_accuracy: 0.9931 - val_dice_coefficient: 0.7134 - val_iou_metric: 0.5600 - val_loss: 0.0164 - learning_rate: 1.0000e-04
# Epoch 37/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9841 - dice_coefficient: 0.7973 - iou_metric: 0.6680 - loss: 0.0286
# Epoch 37: val_loss did not improve from 0.01079
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9841 - dice_coefficient: 0.7974 - iou_metric: 0.6681 - loss: 0.0286 - val_accuracy: 0.9951 - val_dice_coefficient: 0.7718 - val_iou_metric: 0.6310 - val_loss: 0.0109 - learning_rate: 1.0000e-04
# Epoch 38/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9881 - dice_coefficient: 0.8243 - iou_metric: 0.7049 - loss: 0.0190
# Epoch 38: val_loss improved from 0.01079 to 0.00994, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 871ms/step - accuracy: 0.9881 - dice_coefficient: 0.8243 - iou_metric: 0.7049 - loss: 0.0191 - val_accuracy: 0.9955 - val_dice_coefficient: 0.7820 - val_iou_metric: 0.6440 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 39/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9870 - dice_coefficient: 0.8072 - iou_metric: 0.6837 - loss: 0.0212
# Epoch 39: val_loss did not improve from 0.00994
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 856ms/step - accuracy: 0.9870 - dice_coefficient: 0.8073 - iou_metric: 0.6837 - loss: 0.0212 - val_accuracy: 0.9948 - val_dice_coefficient: 0.7089 - val_iou_metric: 0.5522 - val_loss: 0.0128 - learning_rate: 1.0000e-04
# Epoch 40/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9854 - dice_coefficient: 0.8264 - iou_metric: 0.7079 - loss: 0.0239
# Epoch 40: val_loss did not improve from 0.00994
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9854 - dice_coefficient: 0.8264 - iou_metric: 0.7079 - loss: 0.0239 - val_accuracy: 0.9951 - val_dice_coefficient: 0.7827 - val_iou_metric: 0.6456 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 41/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9867 - dice_coefficient: 0.8363 - iou_metric: 0.7231 - loss: 0.0210
# Epoch 41: val_loss improved from 0.00994 to 0.00981, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 873ms/step - accuracy: 0.9867 - dice_coefficient: 0.8363 - iou_metric: 0.7232 - loss: 0.0210 - val_accuracy: 0.9956 - val_dice_coefficient: 0.7948 - val_iou_metric: 0.6611 - val_loss: 0.0098 - learning_rate: 1.0000e-04
# Epoch 42/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9859 - dice_coefficient: 0.8350 - iou_metric: 0.7200 - loss: 0.0226
# Epoch 42: val_loss did not improve from 0.00981
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 119s 853ms/step - accuracy: 0.9859 - dice_coefficient: 0.8350 - iou_metric: 0.7200 - loss: 0.0226 - val_accuracy: 0.9952 - val_dice_coefficient: 0.7934 - val_iou_metric: 0.6600 - val_loss: 0.0106 - learning_rate: 1.0000e-04
# Epoch 43/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9867 - dice_coefficient: 0.8448 - iou_metric: 0.7353 - loss: 0.0203
# Epoch 43: val_loss did not improve from 0.00981
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 859ms/step - accuracy: 0.9867 - dice_coefficient: 0.8447 - iou_metric: 0.7352 - loss: 0.0203 - val_accuracy: 0.9954 - val_dice_coefficient: 0.7937 - val_iou_metric: 0.6609 - val_loss: 0.0108 - learning_rate: 1.0000e-04
# Epoch 44/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9868 - dice_coefficient: 0.8402 - iou_metric: 0.7290 - loss: 0.0205
# Epoch 44: val_loss did not improve from 0.00981
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 856ms/step - accuracy: 0.9868 - dice_coefficient: 0.8401 - iou_metric: 0.7290 - loss: 0.0205 - val_accuracy: 0.9954 - val_dice_coefficient: 0.7809 - val_iou_metric: 0.6427 - val_loss: 0.0102 - learning_rate: 1.0000e-04
# Epoch 45/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9888 - dice_coefficient: 0.8479 - iou_metric: 0.7396 - loss: 0.0168
# Epoch 45: val_loss did not improve from 0.00981
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9888 - dice_coefficient: 0.8480 - iou_metric: 0.7396 - loss: 0.0168 - val_accuracy: 0.9954 - val_dice_coefficient: 0.7896 - val_iou_metric: 0.6546 - val_loss: 0.0104 - learning_rate: 1.0000e-04
# Epoch 46/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9878 - dice_coefficient: 0.8556 - iou_metric: 0.7511 - loss: 0.0177
# Epoch 46: val_loss did not improve from 0.00981
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 858ms/step - accuracy: 0.9878 - dice_coefficient: 0.8556 - iou_metric: 0.7510 - loss: 0.0177 - val_accuracy: 0.9950 - val_dice_coefficient: 0.7869 - val_iou_metric: 0.6509 - val_loss: 0.0113 - learning_rate: 1.0000e-04
# Epoch 47/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9877 - dice_coefficient: 0.8640 - iou_metric: 0.7639 - loss: 0.0176
# Epoch 47: val_loss did not improve from 0.00981
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9877 - dice_coefficient: 0.8639 - iou_metric: 0.7638 - loss: 0.0176 - val_accuracy: 0.9956 - val_dice_coefficient: 0.7861 - val_iou_metric: 0.6495 - val_loss: 0.0101 - learning_rate: 1.0000e-04
# Epoch 48/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9872 - dice_coefficient: 0.8187 - iou_metric: 0.6984 - loss: 0.0214
# Epoch 48: val_loss did not improve from 0.00981
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 861ms/step - accuracy: 0.9871 - dice_coefficient: 0.8186 - iou_metric: 0.6982 - loss: 0.0214 - val_accuracy: 0.9918 - val_dice_coefficient: 0.6303 - val_iou_metric: 0.4645 - val_loss: 0.0201 - learning_rate: 1.0000e-04
# Epoch 49/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9837 - dice_coefficient: 0.7811 - iou_metric: 0.6519 - loss: 0.0291
# Epoch 49: val_loss did not improve from 0.00981
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 856ms/step - accuracy: 0.9837 - dice_coefficient: 0.7814 - iou_metric: 0.6522 - loss: 0.0291 - val_accuracy: 0.9954 - val_dice_coefficient: 0.7853 - val_iou_metric: 0.6491 - val_loss: 0.0103 - learning_rate: 5.0000e-05
# Epoch 50/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.9878 - dice_coefficient: 0.8470 - iou_metric: 0.7383 - loss: 0.0185
# Epoch 50: val_loss improved from 0.00981 to 0.00973, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 873ms/step - accuracy: 0.9878 - dice_coefficient: 0.8471 - iou_metric: 0.7383 - loss: 0.0185 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8056 - val_iou_metric: 0.6767 - val_loss: 0.0097 - learning_rate: 5.0000e-05
# Epoch 51/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.9894 - dice_coefficient: 0.8546 - iou_metric: 0.7495 - loss: 0.0151
# Epoch 51: val_loss improved from 0.00973 to 0.00966, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 867ms/step - accuracy: 0.9894 - dice_coefficient: 0.8546 - iou_metric: 0.7496 - loss: 0.0151 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8083 - val_iou_metric: 0.6804 - val_loss: 0.0097 - learning_rate: 5.0000e-05
# Epoch 52/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9896 - dice_coefficient: 0.8616 - iou_metric: 0.7611 - loss: 0.0144
# Epoch 52: val_loss improved from 0.00966 to 0.00963, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 867ms/step - accuracy: 0.9896 - dice_coefficient: 0.8617 - iou_metric: 0.7612 - loss: 0.0144 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8086 - val_iou_metric: 0.6807 - val_loss: 0.0096 - learning_rate: 5.0000e-05
# Epoch 53/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9888 - dice_coefficient: 0.8681 - iou_metric: 0.7698 - loss: 0.0154
# Epoch 53: val_loss improved from 0.00963 to 0.00962, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 868ms/step - accuracy: 0.9888 - dice_coefficient: 0.8681 - iou_metric: 0.7698 - loss: 0.0154 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8119 - val_iou_metric: 0.6855 - val_loss: 0.0096 - learning_rate: 5.0000e-05
# Epoch 54/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9885 - dice_coefficient: 0.8741 - iou_metric: 0.7790 - loss: 0.0158
# Epoch 54: val_loss did not improve from 0.00962
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9885 - dice_coefficient: 0.8741 - iou_metric: 0.7790 - loss: 0.0158 - val_accuracy: 0.9955 - val_dice_coefficient: 0.8027 - val_iou_metric: 0.6727 - val_loss: 0.0100 - learning_rate: 5.0000e-05
# Epoch 55/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9889 - dice_coefficient: 0.8722 - iou_metric: 0.7771 - loss: 0.0148
# Epoch 55: val_loss did not improve from 0.00962
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 854ms/step - accuracy: 0.9889 - dice_coefficient: 0.8722 - iou_metric: 0.7771 - loss: 0.0148 - val_accuracy: 0.9956 - val_dice_coefficient: 0.8132 - val_iou_metric: 0.6872 - val_loss: 0.0098 - learning_rate: 5.0000e-05
# Epoch 56/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9897 - dice_coefficient: 0.8664 - iou_metric: 0.7679 - loss: 0.0139
# Epoch 56: val_loss did not improve from 0.00962
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 856ms/step - accuracy: 0.9897 - dice_coefficient: 0.8665 - iou_metric: 0.7680 - loss: 0.0139 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8264 - val_iou_metric: 0.7060 - val_loss: 0.0097 - learning_rate: 5.0000e-05
# Epoch 57/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9896 - dice_coefficient: 0.8757 - iou_metric: 0.7819 - loss: 0.0139
# Epoch 57: val_loss improved from 0.00962 to 0.00956, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 868ms/step - accuracy: 0.9896 - dice_coefficient: 0.8757 - iou_metric: 0.7819 - loss: 0.0139 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8187 - val_iou_metric: 0.6950 - val_loss: 0.0096 - learning_rate: 5.0000e-05
# Epoch 58/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9888 - dice_coefficient: 0.8834 - iou_metric: 0.7941 - loss: 0.0144
# Epoch 58: val_loss improved from 0.00956 to 0.00935, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 121s 867ms/step - accuracy: 0.9888 - dice_coefficient: 0.8834 - iou_metric: 0.7941 - loss: 0.0144 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8184 - val_iou_metric: 0.6945 - val_loss: 0.0094 - learning_rate: 5.0000e-05
# Epoch 59/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9898 - dice_coefficient: 0.8776 - iou_metric: 0.7852 - loss: 0.0131
# Epoch 59: val_loss did not improve from 0.00935
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 119s 853ms/step - accuracy: 0.9898 - dice_coefficient: 0.8776 - iou_metric: 0.7852 - loss: 0.0131 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8184 - val_iou_metric: 0.6947 - val_loss: 0.0097 - learning_rate: 5.0000e-05
# Epoch 60/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9894 - dice_coefficient: 0.8821 - iou_metric: 0.7923 - loss: 0.0136
# Epoch 60: val_loss did not improve from 0.00935
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9894 - dice_coefficient: 0.8821 - iou_metric: 0.7923 - loss: 0.0136 - val_accuracy: 0.9956 - val_dice_coefficient: 0.8201 - val_iou_metric: 0.6970 - val_loss: 0.0097 - learning_rate: 5.0000e-05
# Epoch 61/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9889 - dice_coefficient: 0.8869 - iou_metric: 0.7992 - loss: 0.0143
# Epoch 61: val_loss improved from 0.00935 to 0.00902, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 122s 870ms/step - accuracy: 0.9889 - dice_coefficient: 0.8868 - iou_metric: 0.7991 - loss: 0.0143 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8317 - val_iou_metric: 0.7136 - val_loss: 0.0090 - learning_rate: 5.0000e-05
# Epoch 62/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.9900 - dice_coefficient: 0.8832 - iou_metric: 0.7939 - loss: 0.0125
# Epoch 62: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 119s 852ms/step - accuracy: 0.9900 - dice_coefficient: 0.8832 - iou_metric: 0.7939 - loss: 0.0125 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8291 - val_iou_metric: 0.7098 - val_loss: 0.0098 - learning_rate: 5.0000e-05
# Epoch 63/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9887 - dice_coefficient: 0.8895 - iou_metric: 0.8038 - loss: 0.0141
# Epoch 63: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 856ms/step - accuracy: 0.9887 - dice_coefficient: 0.8894 - iou_metric: 0.8037 - loss: 0.0141 - val_accuracy: 0.9955 - val_dice_coefficient: 0.8170 - val_iou_metric: 0.6928 - val_loss: 0.0107 - learning_rate: 5.0000e-05
# Epoch 64/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9893 - dice_coefficient: 0.8810 - iou_metric: 0.7909 - loss: 0.0136
# Epoch 64: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9893 - dice_coefficient: 0.8810 - iou_metric: 0.7910 - loss: 0.0136 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8263 - val_iou_metric: 0.7059 - val_loss: 0.0097 - learning_rate: 5.0000e-05
# Epoch 65/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9894 - dice_coefficient: 0.8844 - iou_metric: 0.7962 - loss: 0.0134
# Epoch 65: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9894 - dice_coefficient: 0.8844 - iou_metric: 0.7962 - loss: 0.0134 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8176 - val_iou_metric: 0.6936 - val_loss: 0.0100 - learning_rate: 5.0000e-05
# Epoch 66/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9904 - dice_coefficient: 0.8826 - iou_metric: 0.7929 - loss: 0.0118
# Epoch 66: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 858ms/step - accuracy: 0.9904 - dice_coefficient: 0.8826 - iou_metric: 0.7929 - loss: 0.0118 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8267 - val_iou_metric: 0.7064 - val_loss: 0.0094 - learning_rate: 5.0000e-05
# Epoch 67/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9898 - dice_coefficient: 0.8710 - iou_metric: 0.7750 - loss: 0.0135
# Epoch 67: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 859ms/step - accuracy: 0.9898 - dice_coefficient: 0.8710 - iou_metric: 0.7751 - loss: 0.0135 - val_accuracy: 0.9956 - val_dice_coefficient: 0.8244 - val_iou_metric: 0.7032 - val_loss: 0.0106 - learning_rate: 5.0000e-05
# Epoch 68/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9878 - dice_coefficient: 0.8692 - iou_metric: 0.7735 - loss: 0.0171
# Epoch 68: val_loss did not improve from 0.00902
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 854ms/step - accuracy: 0.9878 - dice_coefficient: 0.8692 - iou_metric: 0.7735 - loss: 0.0171 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8238 - val_iou_metric: 0.7021 - val_loss: 0.0095 - learning_rate: 5.0000e-05
# Epoch 69/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9889 - dice_coefficient: 0.8852 - iou_metric: 0.7972 - loss: 0.0140
# Epoch 69: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9889 - dice_coefficient: 0.8852 - iou_metric: 0.7972 - loss: 0.0140 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8303 - val_iou_metric: 0.7116 - val_loss: 0.0094 - learning_rate: 2.5000e-05
# Epoch 70/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9900 - dice_coefficient: 0.8890 - iou_metric: 0.8033 - loss: 0.0122
# Epoch 70: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9900 - dice_coefficient: 0.8890 - iou_metric: 0.8033 - loss: 0.0122 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8301 - val_iou_metric: 0.7113 - val_loss: 0.0094 - learning_rate: 2.5000e-05
# Epoch 71/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 803ms/step - accuracy: 0.9903 - dice_coefficient: 0.8896 - iou_metric: 0.8042 - loss: 0.0116
# Epoch 71: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 858ms/step - accuracy: 0.9903 - dice_coefficient: 0.8897 - iou_metric: 0.8042 - loss: 0.0116 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8291 - val_iou_metric: 0.7099 - val_loss: 0.0096 - learning_rate: 2.5000e-05
# Epoch 72/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 799ms/step - accuracy: 0.9901 - dice_coefficient: 0.8955 - iou_metric: 0.8137 - loss: 0.0117
# Epoch 72: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9901 - dice_coefficient: 0.8955 - iou_metric: 0.8137 - loss: 0.0117 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8315 - val_iou_metric: 0.7134 - val_loss: 0.0094 - learning_rate: 2.5000e-05
# Epoch 73/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9899 - dice_coefficient: 0.8981 - iou_metric: 0.8182 - loss: 0.0118
# Epoch 73: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9899 - dice_coefficient: 0.8981 - iou_metric: 0.8182 - loss: 0.0118 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8331 - val_iou_metric: 0.7158 - val_loss: 0.0100 - learning_rate: 2.5000e-05
# Epoch 74/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9895 - dice_coefficient: 0.9053 - iou_metric: 0.8295 - loss: 0.0120
# Epoch 74: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 856ms/step - accuracy: 0.9895 - dice_coefficient: 0.9052 - iou_metric: 0.8294 - loss: 0.0120 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8337 - val_iou_metric: 0.7168 - val_loss: 0.0100 - learning_rate: 2.5000e-05
# Epoch 75/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.9908 - dice_coefficient: 0.8947 - iou_metric: 0.8124 - loss: 0.0106
# Epoch 75: val_loss did not improve from 0.00902
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 857ms/step - accuracy: 0.9908 - dice_coefficient: 0.8948 - iou_metric: 0.8125 - loss: 0.0106 - val_accuracy: 0.9959 - val_dice_coefficient: 0.8337 - val_iou_metric: 0.7167 - val_loss: 0.0095 - learning_rate: 2.5000e-05
# Epoch 76/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.9898 - dice_coefficient: 0.9006 - iou_metric: 0.8216 - loss: 0.0116
# Epoch 76: val_loss did not improve from 0.00902
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 120s 855ms/step - accuracy: 0.9898 - dice_coefficient: 0.9005 - iou_metric: 0.8216 - loss: 0.0116 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8351 - val_iou_metric: 0.7189 - val_loss: 0.0099 - learning_rate: 1.2500e-05
# Epoch 76: early stopping
# Restoring model weights from the end of the best epoch: 61.

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    """
    Plots the training and validation accuracy and loss over epochs.

    Args:
        history (tf.keras.callbacks.History): The history object returned by model.fit.

    Returns:
        None
    """
    # Extract metrics from the history object
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)  # Epochs for the x-axis

    # Plot training and validation accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage
plot_training_history(history)

# %%
# Predict on the test dataset
test_predictions = model.predict(test_generator)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 224ms/step

# %%
# Evaluate the model on the test data
test_loss, test_accuracy, test_dice, test_iou = model.evaluate(test_generator, verbose=1)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 7s 197ms/step - accuracy: 0.9959 - dice_coefficient: 0.8201 - iou_metric: 0.6965 - loss: 0.0093
# Test Accuracy: 0.9959

# %%
print(f"Test Dice Coefficient: {test_dice:.4f}")
print(f"Test IoU: {test_iou:.4f}")
# Out:
# Test Dice Coefficient: 0.8317
# Test IoU: 0.7136

# %%
import matplotlib.pyplot as plt

def plot_training_history(history, test_accuracy=None):
    """
    Plots the training and validation accuracy and loss over epochs.
    Optionally, adds a horizontal line for Test Accuracy.

    Args:
        history (tf.keras.callbacks.History): The history object returned by model.fit.
        test_accuracy (float): Test accuracy to display on the plot (optional).

    Returns:
        None
    """
    # Extract metrics from the history object
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)  # Epochs for the x-axis

    # Plot training and validation accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
    
    # Add Test Accuracy as a horizontal line
    if test_accuracy is not None:
        plt.axhline(y=test_accuracy, color='g', linestyle='--', label=f'Test Accuracy: {test_accuracy:.4f}')
    
    plt.title('Training, Validation, and Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Evaluate the model on the test data
test_loss, test_accuracy, test_dice, test_iou = model.evaluate(test_generator, verbose=1)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Dice Coefficient: {test_dice:.4f}")
print(f"Test IoU: {test_iou:.4f}")

# Plot training history with Test Accuracy
plot_training_history(history, test_accuracy)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - accuracy: 0.9959 - dice_coefficient: 0.8201 - iou_metric: 0.6965 - loss: 0.0093
# Test Accuracy: 0.9959
# Test Dice Coefficient: 0.8317
# Test IoU: 0.7136

# %%
# Save the model in .h5 format
model.save('unet_wound_segmentation_model.h5')

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images/fusc_0021.png'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images/fusc_0024.png'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images/fusc_0030.png'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 797ms/step
