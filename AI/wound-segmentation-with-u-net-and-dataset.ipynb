# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from tqdm import tqdm
import cv2
import itertools

import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K

from sklearn.metrics import confusion_matrix

# Set matplotlib to display plots inline in Jupyter notebooks
# %matplotlib inline

# %%
import os
from glob import glob

# Define paths for training and testing data
TRAIN_IMAGE_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/train_images'
TRAIN_MASK_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/train_masks'
TEST_IMAGE_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images'
TEST_MASK_DIR = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_masks'
CORRESPONDENCE_TABLE_PATH = '/kaggle/input/wound-segmentation-images/data_wound_seg/correspondence_table.xlsx'

def get_file_paths(image_dir, mask_dir, file_extension='*.png'):
    """
    Retrieves sorted lists of image and mask file paths from the specified directories.

    Args:
        image_dir (str): Directory containing image files.
        mask_dir (str): Directory containing mask files.
        file_extension (str): File extension to filter files (default is '*.png').

    Returns:
        tuple: Two lists containing sorted image paths and mask paths.
    """
    images = sorted(glob(os.path.join(image_dir, file_extension)))
    masks = sorted(glob(os.path.join(mask_dir, file_extension)))
    return images, masks

def validate_dataset(images, masks, dataset_name):
    """
    Validates that the number of images and masks match and prints the count.

    Args:
        images (list): List of image file paths.
        masks (list): List of mask file paths.
        dataset_name (str): Name of the dataset (e.g., 'training', 'testing').

    Raises:
        ValueError: If the number of images and masks do not match.
    """
    if len(images) != len(masks):
        raise ValueError(f"Mismatch in {dataset_name} dataset: {len(images)} images vs {len(masks)} masks.")
    print(f"Number of {dataset_name} images: {len(images)}")
    print(f"Number of {dataset_name} masks: {len(masks)}")

# Get file paths for training and testing datasets
train_images, train_masks = get_file_paths(TRAIN_IMAGE_DIR, TRAIN_MASK_DIR)
test_images, test_masks = get_file_paths(TEST_IMAGE_DIR, TEST_MASK_DIR)

# Validate and print dataset sizes
validate_dataset(train_images, train_masks, 'training')
validate_dataset(test_images, test_masks, 'testing')
# Out:
# Number of training images: 2208
# Number of training masks: 2208
# Number of testing images: 552
# Number of testing masks: 552

# %%
import matplotlib.pyplot as plt
import cv2

def display_samples(images, masks, num_samples=5):
    """
    Displays a sample of images and their corresponding masks side by side.

    Args:
        images (list): List of paths to image files.
        masks (list): List of paths to mask files.
        num_samples (int): Number of samples to display (default is 5).

    Raises:
        ValueError: If the number of images and masks do not match.
    """
    if len(images) != len(masks):
        raise ValueError("The number of images and masks must be the same.")

    # Set up the figure for visualization
    plt.figure(figsize=(12, num_samples * 4))

    for i in range(num_samples):
        # Load and preprocess the image
        img = cv2.imread(images[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct display

        # Load the mask in grayscale
        mask = cv2.imread(masks[i], cv2.IMREAD_GRAYSCALE)

        # Display the image
        plt.subplot(num_samples, 2, 2 * i + 1)
        plt.imshow(img)
        plt.title(f'Image {i + 1}')
        plt.axis('off')

        # Display the corresponding mask
        plt.subplot(num_samples, 2, 2 * i + 2)
        plt.imshow(mask, cmap='gray')
        plt.title(f'Mask {i + 1}')
        plt.axis('off')

    # Adjust layout for better visualization
    plt.tight_layout()
    plt.show()

# Example usage: Display 3 samples from the training set
display_samples(train_images, train_masks, num_samples=3)

# %%
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence

# Constants for configuration
IMG_HEIGHT = 256  # Target image height
IMG_WIDTH = 256   # Target image width
BATCH_SIZE = 16   # Batch size for training
NORMALIZE_FACTOR = 255.0  # Normalization factor for pixel values

class DataGenerator(Sequence):
    """
    Custom data generator for loading and augmenting images and masks in batches.

    Args:
        image_filenames (list): List of paths to image files.
        mask_filenames (list): List of paths to mask files.
        batch_size (int): Number of samples per batch.
        img_height (int): Target height for resizing images and masks.
        img_width (int): Target width for resizing images and masks.
        augment (bool): Whether to apply data augmentation (default is False).
    """

    def __init__(self, image_filenames, mask_filenames, batch_size, img_height, img_width, augment=False):
        self.image_filenames = image_filenames
        self.mask_filenames = mask_filenames
        self.batch_size = batch_size
        self.img_height = img_height
        self.img_width = img_width
        self.augment = augment

    def __len__(self):
        """Returns the number of batches per epoch."""
        return int(np.ceil(len(self.image_filenames) / self.batch_size))

    def __getitem__(self, idx):
        """Generates one batch of data."""
        batch_x = self.image_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.mask_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]

        images, masks = [], []
        for img_path, mask_path in zip(batch_x, batch_y):
            img = self._load_and_preprocess_image(img_path)
            mask = self._load_and_preprocess_mask(mask_path)

            if self.augment:
                img, mask = self._apply_augmentation(img, mask)

            images.append(img)
            masks.append(mask)

        return np.array(images), np.array(masks)

    def _load_and_preprocess_image(self, img_path):
        """Loads and preprocesses an image."""
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
        img = cv2.resize(img, (self.img_width, self.img_height))  # Resize
        img = img / NORMALIZE_FACTOR  # Normalize to [0, 1]
        img = img.astype(np.float32)  # Cast to float32
        return img

    def _load_and_preprocess_mask(self, mask_path):
        """Loads and preprocesses a mask."""
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
        mask = cv2.resize(mask, (self.img_width, self.img_height))  # Resize
        mask = np.expand_dims(mask, axis=-1)  # Add channel dimension
        mask = mask / NORMALIZE_FACTOR  # Normalize to [0, 1]
        mask = mask.astype(np.float32)  # Cast to float32
        return mask

    def _apply_augmentation(self, img, mask):
        """Applies random augmentation to an image and its mask."""
        # Random horizontal flip
        if np.random.rand() > 0.5:
            img = np.fliplr(img)
            mask = np.fliplr(mask)

        # Random vertical flip
        if np.random.rand() > 0.5:
            img = np.flipud(img)
            mask = np.flipud(mask)

        # Random rotation
        angle = np.random.randint(-15, 15)
        M = cv2.getRotationMatrix2D((self.img_width / 2, self.img_height / 2), angle, 1)
        img = cv2.warpAffine(img, M, (self.img_width, self.img_height)).astype(np.float32)
        mask = cv2.warpAffine(mask, M, (self.img_width, self.img_height)).astype(np.float32)

        return img, mask

# Create data generators
train_generator = DataGenerator(train_images, train_masks, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH, augment=True)
test_generator = DataGenerator(test_images, test_masks, BATCH_SIZE, IMG_HEIGHT, IMG_WIDTH)

# %%
import numpy as np
import cv2
from tensorflow.keras.utils import Sequence

class DataGenerator(Sequence):
    """
    Custom data generator for loading and augmenting images and masks in batches.

    Args:
        image_filenames (list): List of paths to image files.
        mask_filenames (list): List of paths to mask files.
        batch_size (int): Number of samples per batch.
        img_height (int): Target height for resizing images and masks.
        img_width (int): Target width for resizing images and masks.
        augment (bool): Whether to apply data augmentation (default is False).
    """

    def __init__(self, image_filenames, mask_filenames, batch_size, img_height, img_width, augment=False):
        self.image_filenames = image_filenames
        self.mask_filenames = mask_filenames
        self.batch_size = batch_size
        self.img_height = img_height
        self.img_width = img_width
        self.augment = augment

    def __len__(self):
        """Returns the number of batches per epoch."""
        return int(np.ceil(len(self.image_filenames) / self.batch_size))

    def __getitem__(self, idx):
        """Generates one batch of data."""
        batch_x = self.image_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_y = self.mask_filenames[idx * self.batch_size:(idx + 1) * self.batch_size]

        images, masks = [], []
        for img_path, mask_path in zip(batch_x, batch_y):
            img = self._load_and_preprocess_image(img_path)
            mask = self._load_and_preprocess_mask(mask_path)

            if self.augment:
                img, mask = self._apply_augmentation(img, mask)

            images.append(img)
            masks.append(mask)

        return np.array(images), np.array(masks)

    def _load_and_preprocess_image(self, img_path):
        """Loads and preprocesses an image."""
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
        img = cv2.resize(img, (self.img_width, self.img_height))  # Resize
        img = img / 255.0  # Normalize to [0, 1]
        return img

    def _load_and_preprocess_mask(self, mask_path):
        """Loads and preprocesses a mask."""
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
        mask = cv2.resize(mask, (self.img_width, self.img_height))  # Resize
        mask = np.expand_dims(mask, axis=-1)  # Add channel dimension
        mask = mask / 255.0  # Normalize to [0, 1]
        return mask

    def _apply_augmentation(self, img, mask):
        """Applies random augmentation to an image and its mask."""
        # Random horizontal flip
        if np.random.rand() > 0.5:
            img = np.fliplr(img)
            mask = np.fliplr(mask)

        # Random vertical flip
        if np.random.rand() > 0.5:
            img = np.flipud(img)
            mask = np.flipud(mask)

        # Random rotation
        angle = np.random.randint(-15, 15)
        M = cv2.getRotationMatrix2D((self.img_width / 2, self.img_height / 2), angle, 1)
        img = cv2.warpAffine(img, M, (self.img_width, self.img_height))
        mask = cv2.warpAffine(mask, M, (self.img_width, self.img_height))

        return img, mask

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dropout, MaxPooling2D, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model

def unet_model(input_size=(256, 256, 3)):
    """
    Defines a U-Net model for image segmentation.

    Args:
        input_size (tuple): Input image dimensions (height, width, channels). Default is (256, 256, 3).

    Returns:
        model (tf.keras.Model): A U-Net model.
    """
    inputs = Input(input_size)

    # Encoder (Downsampling Path)
    def encoder_block(input_tensor, filters, dropout_rate):
        """Creates an encoder block with two convolutional layers, batch normalization, and dropout."""
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(input_tensor)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rate)(x)
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        p = MaxPooling2D((2, 2))(x)
        return x, p

    c1, p1 = encoder_block(inputs, 64, 0.1)
    c2, p2 = encoder_block(p1, 128, 0.1)
    c3, p3 = encoder_block(p2, 256, 0.2)
    c4, p4 = encoder_block(p3, 512, 0.2)

    # Bridge
    bridge = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    bridge = BatchNormalization()(bridge)
    bridge = Dropout(0.3)(bridge)
    bridge = Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)

    # Decoder (Upsampling Path)
    def decoder_block(input_tensor, skip_tensor, filters, dropout_rate):
        """Creates a decoder block with upsampling, concatenation, and two convolutional layers."""
        x = Conv2DTranspose(filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
        x = concatenate([x, skip_tensor])
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rate)(x)
        x = Conv2D(filters, (3, 3), activation='relu', padding='same')(x)
        return x

    d1 = decoder_block(bridge, c4, 512, 0.2)
    d2 = decoder_block(d1, c3, 256, 0.2)
    d3 = decoder_block(d2, c2, 128, 0.1)
    d4 = decoder_block(d3, c1, 64, 0.1)

    # Output Layer
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(d4)

    # Create the model
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# Instantiate the model
model = unet_model()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 128, 128, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 64, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 32, 32, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 32, 32, 512)    │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 512)    │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 16, 16, 1024)   │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 16, 16, 1024)   │          4,096 │ conv2d_8[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 16, 16, 1024)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 16, 16, 1024)   │      9,438,208 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 512)    │      2,097,664 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 32, 32, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 32, 32, 512)    │      4,719,104 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 32, 32, 512)    │          2,048 │ conv2d_10[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 32, 32, 512)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 64, 64, 256)    │        524,544 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 64, 64, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 64, 64, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 128, 128, 128)  │        131,200 │ conv2d_13[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 128)  │        295,040 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 128, 128, 128)  │            512 │ conv2d_14[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128, 128, 128)  │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ dropout_7[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 256, 256, 64)   │         32,832 │ conv2d_15[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 256, 256, 64)   │         73,792 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 256, 256, 64)   │            256 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 256, 256, 64)   │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ dropout_8[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ conv2d_17[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,043,521 (118.42 MB)
#  Trainable params: 31,037,633 (118.40 MB)
#  Non-trainable params: 5,888 (23.00 KB)

# %%
import tensorflow.keras.backend as K

def dice_coefficient(y_true, y_pred, smooth=1):
    """
    Computes the Dice Coefficient, a metric for evaluating segmentation performance.

    Args:
        y_true (tensor): Ground truth labels.
        y_pred (tensor): Predicted labels.
        smooth (float): Smoothing factor to avoid division by zero. Default is 1.

    Returns:
        dice (tensor): Dice Coefficient score.
    """
    # Flatten and cast tensors to float32
    y_true_f = K.flatten(K.cast(y_true, 'float32'))
    y_pred_f = K.flatten(K.cast(y_pred, 'float32'))

    # Compute intersection and Dice Coefficient
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def iou_metric(y_true, y_pred, smooth=1):
    """
    Computes the Intersection over Union (IoU), a metric for evaluating segmentation performance.

    Args:
        y_true (tensor): Ground truth labels.
        y_pred (tensor): Predicted labels.
        smooth (float): Smoothing factor to avoid division by zero. Default is 1.

    Returns:
        iou (tensor): IoU score.
    """
    # Flatten and cast tensors to float32
    y_true_f = K.flatten(K.cast(y_true, 'float32'))
    y_pred_f = K.flatten(K.cast(y_pred, 'float32'))

    # Compute intersection and union
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection

    # Compute IoU
    iou = (intersection + smooth) / (union + smooth)
    return iou

# %%
from tensorflow.keras.optimizers import Adam

# Compile the model with specified optimizer, loss function, and metrics
model.compile(
    optimizer=Adam(learning_rate=1e-4),  # Use Adam optimizer with a learning rate of 1e-4
    loss='binary_crossentropy',          # Use binary cross-entropy as the loss function
    metrics=[
        'accuracy',                      # Track accuracy during training
        dice_coefficient,                # Use Dice Coefficient as a custom metric
        iou_metric                       # Use Intersection over Union (IoU) as a custom metric
    ]
)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Define callbacks for training
def get_callbacks():
    """
    Creates and returns a list of callbacks for model training.

    Returns:
        list: A list of callbacks including ModelCheckpoint, EarlyStopping, and ReduceLROnPlateau.
    """
    # Save the best model based on validation loss
    checkpoint = ModelCheckpoint(
        'unet_wound_segmentation_best.keras',  # Save model with .keras extension
        monitor='val_loss',                    # Monitor validation loss
        save_best_only=True,                   # Save only the best model
        verbose=1,                             # Log progress
        mode='min'                             # Minimize validation loss
    )

    # Stop training early if validation loss does not improve
    earlystop = EarlyStopping(
        monitor='val_loss',                    # Monitor validation loss
        patience=15,                           # Wait for 15 epochs without improvement
        verbose=1,                             # Log progress
        restore_best_weights=True              # Restore the best model weights
    )

    # Reduce learning rate if validation loss plateaus
    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',                    # Monitor validation loss
        factor=0.5,                            # Reduce learning rate by 50%
        patience=7,                            # Wait for 7 epochs without improvement
        verbose=1,                             # Log progress
        mode='min',                            # Minimize validation loss
        min_lr=1e-6                            # Minimum learning rate
    )

    return [checkpoint, earlystop, reduce_lr]

# Compile the model
def compile_model(model):
    """
    Compiles the model with Adam optimizer, binary cross-entropy loss, and custom metrics.

    Args:
        model (tf.keras.Model): The model to compile.

    Returns:
        None
    """
    model.compile(
        optimizer=Adam(learning_rate=1e-4),    # Use Adam optimizer with a learning rate of 1e-4
        loss='binary_crossentropy',            # Use binary cross-entropy loss
        metrics=['accuracy', dice_coefficient, iou_metric]  # Track accuracy, Dice Coefficient, and IoU
    )

# Train the model
def train_model(model, train_generator, test_generator, epochs=100):
    """
    Trains the model using the provided data generators and callbacks.

    Args:
        model (tf.keras.Model): The model to train.
        train_generator (DataGenerator): Training data generator.
        test_generator (DataGenerator): Validation data generator.
        epochs (int): Number of training epochs. Default is 100.

    Returns:
        history: Training history object.
    """
    callbacks_list = get_callbacks()  # Get the list of callbacks

    history = model.fit(
        train_generator,
        validation_data=test_generator,
        epochs=epochs,                # Number of training epochs
        callbacks=callbacks_list,     # Use defined callbacks
        verbose=1                     # Log progress
    )
    return history

# Example usage
compile_model(model)  # Compile the model
history = train_model(model, train_generator, test_generator, epochs=100)  # Train the model
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9417 - dice_coefficient: 0.1438 - iou_metric: 0.0801 - loss: 0.1977
# Epoch 1: val_loss improved from inf to 0.09340, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 265s 1s/step - accuracy: 0.9418 - dice_coefficient: 0.1442 - iou_metric: 0.0804 - loss: 0.1973 - val_accuracy: 0.9860 - val_dice_coefficient: 0.0209 - val_iou_metric: 0.0106 - val_loss: 0.0934 - learning_rate: 1.0000e-04
# Epoch 2/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9577 - dice_coefficient: 0.3289 - iou_metric: 0.2028 - loss: 0.1082
# Epoch 2: val_loss improved from 0.09340 to 0.08018, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 914ms/step - accuracy: 0.9577 - dice_coefficient: 0.3289 - iou_metric: 0.2028 - loss: 0.1081 - val_accuracy: 0.9860 - val_dice_coefficient: 0.0060 - val_iou_metric: 0.0030 - val_loss: 0.0802 - learning_rate: 1.0000e-04
# Epoch 3/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9624 - dice_coefficient: 0.3983 - iou_metric: 0.2538 - loss: 0.0896
# Epoch 3: val_loss did not improve from 0.08018
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 901ms/step - accuracy: 0.9624 - dice_coefficient: 0.3984 - iou_metric: 0.2539 - loss: 0.0896 - val_accuracy: 0.9860 - val_dice_coefficient: 9.4532e-04 - val_iou_metric: 5.1140e-04 - val_loss: 0.1095 - learning_rate: 1.0000e-04
# Epoch 4/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.9667 - dice_coefficient: 0.4534 - iou_metric: 0.3010 - loss: 0.0798
# Epoch 4: val_loss improved from 0.08018 to 0.07918, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 916ms/step - accuracy: 0.9667 - dice_coefficient: 0.4534 - iou_metric: 0.3010 - loss: 0.0798 - val_accuracy: 0.9738 - val_dice_coefficient: 0.1903 - val_iou_metric: 0.1060 - val_loss: 0.0792 - learning_rate: 1.0000e-04
# Epoch 5/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.9675 - dice_coefficient: 0.4607 - iou_metric: 0.3071 - loss: 0.0771
# Epoch 5: val_loss improved from 0.07918 to 0.03618, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 917ms/step - accuracy: 0.9675 - dice_coefficient: 0.4609 - iou_metric: 0.3072 - loss: 0.0771 - val_accuracy: 0.9884 - val_dice_coefficient: 0.3431 - val_iou_metric: 0.2114 - val_loss: 0.0362 - learning_rate: 1.0000e-04
# Epoch 6/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.9678 - dice_coefficient: 0.5487 - iou_metric: 0.3860 - loss: 0.0716
# Epoch 6: val_loss improved from 0.03618 to 0.02172, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 914ms/step - accuracy: 0.9678 - dice_coefficient: 0.5488 - iou_metric: 0.3861 - loss: 0.0715 - val_accuracy: 0.9915 - val_dice_coefficient: 0.5185 - val_iou_metric: 0.3546 - val_loss: 0.0217 - learning_rate: 1.0000e-04
# Epoch 7/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.9736 - dice_coefficient: 0.5575 - iou_metric: 0.3958 - loss: 0.0600
# Epoch 7: val_loss improved from 0.02172 to 0.01639, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 914ms/step - accuracy: 0.9736 - dice_coefficient: 0.5576 - iou_metric: 0.3959 - loss: 0.0600 - val_accuracy: 0.9934 - val_dice_coefficient: 0.6487 - val_iou_metric: 0.4841 - val_loss: 0.0164 - learning_rate: 1.0000e-04
# Epoch 8/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9753 - dice_coefficient: 0.5861 - iou_metric: 0.4228 - loss: 0.0555
# Epoch 8: val_loss did not improve from 0.01639
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 130s 932ms/step - accuracy: 0.9753 - dice_coefficient: 0.5862 - iou_metric: 0.4230 - loss: 0.0555 - val_accuracy: 0.9929 - val_dice_coefficient: 0.5746 - val_iou_metric: 0.4079 - val_loss: 0.0201 - learning_rate: 1.0000e-04
# Epoch 9/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9781 - dice_coefficient: 0.6390 - iou_metric: 0.4783 - loss: 0.0475
# Epoch 9: val_loss did not improve from 0.01639
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 903ms/step - accuracy: 0.9781 - dice_coefficient: 0.6390 - iou_metric: 0.4783 - loss: 0.0475 - val_accuracy: 0.9937 - val_dice_coefficient: 0.5986 - val_iou_metric: 0.4313 - val_loss: 0.0187 - learning_rate: 1.0000e-04
# Epoch 10/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9744 - dice_coefficient: 0.6483 - iou_metric: 0.4884 - loss: 0.0556
# Epoch 10: val_loss improved from 0.01639 to 0.01594, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 916ms/step - accuracy: 0.9744 - dice_coefficient: 0.6483 - iou_metric: 0.4885 - loss: 0.0555 - val_accuracy: 0.9936 - val_dice_coefficient: 0.6730 - val_iou_metric: 0.5122 - val_loss: 0.0159 - learning_rate: 1.0000e-04
# Epoch 11/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9780 - dice_coefficient: 0.6681 - iou_metric: 0.5082 - loss: 0.0482
# Epoch 11: val_loss did not improve from 0.01594
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 898ms/step - accuracy: 0.9780 - dice_coefficient: 0.6682 - iou_metric: 0.5082 - loss: 0.0481 - val_accuracy: 0.9934 - val_dice_coefficient: 0.6628 - val_iou_metric: 0.5013 - val_loss: 0.0170 - learning_rate: 1.0000e-04
# Epoch 12/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.9799 - dice_coefficient: 0.6888 - iou_metric: 0.5321 - loss: 0.0416
# Epoch 12: val_loss did not improve from 0.01594
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 900ms/step - accuracy: 0.9799 - dice_coefficient: 0.6888 - iou_metric: 0.5320 - loss: 0.0416 - val_accuracy: 0.9930 - val_dice_coefficient: 0.6466 - val_iou_metric: 0.4830 - val_loss: 0.0189 - learning_rate: 1.0000e-04
# Epoch 13/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9800 - dice_coefficient: 0.6872 - iou_metric: 0.5304 - loss: 0.0411
# Epoch 13: val_loss improved from 0.01594 to 0.01493, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 910ms/step - accuracy: 0.9800 - dice_coefficient: 0.6873 - iou_metric: 0.5305 - loss: 0.0411 - val_accuracy: 0.9941 - val_dice_coefficient: 0.6825 - val_iou_metric: 0.5218 - val_loss: 0.0149 - learning_rate: 1.0000e-04
# Epoch 14/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9796 - dice_coefficient: 0.7004 - iou_metric: 0.5490 - loss: 0.0433
# Epoch 14: val_loss did not improve from 0.01493
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 900ms/step - accuracy: 0.9796 - dice_coefficient: 0.7004 - iou_metric: 0.5490 - loss: 0.0433 - val_accuracy: 0.9938 - val_dice_coefficient: 0.6935 - val_iou_metric: 0.5366 - val_loss: 0.0164 - learning_rate: 1.0000e-04
# Epoch 15/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9785 - dice_coefficient: 0.6663 - iou_metric: 0.5084 - loss: 0.0453
# Epoch 15: val_loss improved from 0.01493 to 0.01336, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 912ms/step - accuracy: 0.9785 - dice_coefficient: 0.6664 - iou_metric: 0.5085 - loss: 0.0453 - val_accuracy: 0.9944 - val_dice_coefficient: 0.7103 - val_iou_metric: 0.5545 - val_loss: 0.0134 - learning_rate: 1.0000e-04
# Epoch 16/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9818 - dice_coefficient: 0.7416 - iou_metric: 0.5954 - loss: 0.0358
# Epoch 16: val_loss did not improve from 0.01336
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 897ms/step - accuracy: 0.9818 - dice_coefficient: 0.7415 - iou_metric: 0.5953 - loss: 0.0358 - val_accuracy: 0.9946 - val_dice_coefficient: 0.6991 - val_iou_metric: 0.5410 - val_loss: 0.0136 - learning_rate: 1.0000e-04
# Epoch 17/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9803 - dice_coefficient: 0.7313 - iou_metric: 0.5830 - loss: 0.0397
# Epoch 17: val_loss did not improve from 0.01336
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 899ms/step - accuracy: 0.9803 - dice_coefficient: 0.7312 - iou_metric: 0.5830 - loss: 0.0397 - val_accuracy: 0.9944 - val_dice_coefficient: 0.6772 - val_iou_metric: 0.5153 - val_loss: 0.0135 - learning_rate: 1.0000e-04
# Epoch 18/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9816 - dice_coefficient: 0.7461 - iou_metric: 0.6012 - loss: 0.0365
# Epoch 18: val_loss did not improve from 0.01336
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 898ms/step - accuracy: 0.9817 - dice_coefficient: 0.7461 - iou_metric: 0.6012 - loss: 0.0365 - val_accuracy: 0.9945 - val_dice_coefficient: 0.7391 - val_iou_metric: 0.5891 - val_loss: 0.0137 - learning_rate: 1.0000e-04
# Epoch 19/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9857 - dice_coefficient: 0.7397 - iou_metric: 0.5941 - loss: 0.0273
# Epoch 19: val_loss improved from 0.01336 to 0.01255, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 128s 914ms/step - accuracy: 0.9857 - dice_coefficient: 0.7398 - iou_metric: 0.5942 - loss: 0.0273 - val_accuracy: 0.9946 - val_dice_coefficient: 0.7386 - val_iou_metric: 0.5888 - val_loss: 0.0126 - learning_rate: 1.0000e-04
# Epoch 20/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9833 - dice_coefficient: 0.7512 - iou_metric: 0.6111 - loss: 0.0320
# Epoch 20: val_loss improved from 0.01255 to 0.01191, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 911ms/step - accuracy: 0.9833 - dice_coefficient: 0.7513 - iou_metric: 0.6111 - loss: 0.0320 - val_accuracy: 0.9949 - val_dice_coefficient: 0.7523 - val_iou_metric: 0.6056 - val_loss: 0.0119 - learning_rate: 1.0000e-04
# Epoch 21/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9843 - dice_coefficient: 0.7824 - iou_metric: 0.6487 - loss: 0.0283
# Epoch 21: val_loss did not improve from 0.01191
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 896ms/step - accuracy: 0.9843 - dice_coefficient: 0.7823 - iou_metric: 0.6486 - loss: 0.0283 - val_accuracy: 0.9943 - val_dice_coefficient: 0.7149 - val_iou_metric: 0.5610 - val_loss: 0.0140 - learning_rate: 1.0000e-04
# Epoch 22/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9816 - dice_coefficient: 0.7445 - iou_metric: 0.6002 - loss: 0.0353
# Epoch 22: val_loss did not improve from 0.01191
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 898ms/step - accuracy: 0.9816 - dice_coefficient: 0.7446 - iou_metric: 0.6004 - loss: 0.0352 - val_accuracy: 0.9951 - val_dice_coefficient: 0.7527 - val_iou_metric: 0.6066 - val_loss: 0.0120 - learning_rate: 1.0000e-04
# Epoch 23/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9848 - dice_coefficient: 0.7819 - iou_metric: 0.6479 - loss: 0.0273
# Epoch 23: val_loss did not improve from 0.01191
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 897ms/step - accuracy: 0.9848 - dice_coefficient: 0.7819 - iou_metric: 0.6479 - loss: 0.0273 - val_accuracy: 0.9946 - val_dice_coefficient: 0.7266 - val_iou_metric: 0.5732 - val_loss: 0.0131 - learning_rate: 1.0000e-04
# Epoch 24/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9855 - dice_coefficient: 0.7840 - iou_metric: 0.6518 - loss: 0.0267
# Epoch 24: val_loss did not improve from 0.01191
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 910ms/step - accuracy: 0.9855 - dice_coefficient: 0.7840 - iou_metric: 0.6519 - loss: 0.0267 - val_accuracy: 0.9948 - val_dice_coefficient: 0.7170 - val_iou_metric: 0.5617 - val_loss: 0.0122 - learning_rate: 1.0000e-04
# Epoch 25/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9851 - dice_coefficient: 0.7799 - iou_metric: 0.6473 - loss: 0.0267
# Epoch 25: val_loss did not improve from 0.01191
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 130s 917ms/step - accuracy: 0.9851 - dice_coefficient: 0.7800 - iou_metric: 0.6474 - loss: 0.0267 - val_accuracy: 0.9948 - val_dice_coefficient: 0.7293 - val_iou_metric: 0.5771 - val_loss: 0.0123 - learning_rate: 1.0000e-04
# Epoch 26/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.9853 - dice_coefficient: 0.7848 - iou_metric: 0.6512 - loss: 0.0264
# Epoch 26: val_loss did not improve from 0.01191
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 899ms/step - accuracy: 0.9853 - dice_coefficient: 0.7848 - iou_metric: 0.6512 - loss: 0.0264 - val_accuracy: 0.9937 - val_dice_coefficient: 0.7158 - val_iou_metric: 0.5616 - val_loss: 0.0151 - learning_rate: 1.0000e-04
# Epoch 27/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9858 - dice_coefficient: 0.7989 - iou_metric: 0.6715 - loss: 0.0243
# Epoch 27: val_loss did not improve from 0.01191
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 897ms/step - accuracy: 0.9857 - dice_coefficient: 0.7989 - iou_metric: 0.6715 - loss: 0.0243 - val_accuracy: 0.9915 - val_dice_coefficient: 0.5613 - val_iou_metric: 0.3942 - val_loss: 0.0241 - learning_rate: 1.0000e-04
# Epoch 28/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9834 - dice_coefficient: 0.7612 - iou_metric: 0.6225 - loss: 0.0305
# Epoch 28: val_loss improved from 0.01191 to 0.01085, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 911ms/step - accuracy: 0.9834 - dice_coefficient: 0.7614 - iou_metric: 0.6228 - loss: 0.0305 - val_accuracy: 0.9953 - val_dice_coefficient: 0.7800 - val_iou_metric: 0.6419 - val_loss: 0.0108 - learning_rate: 5.0000e-05
# Epoch 29/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9858 - dice_coefficient: 0.8318 - iou_metric: 0.7161 - loss: 0.0227
# Epoch 29: val_loss did not improve from 0.01085
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 903ms/step - accuracy: 0.9858 - dice_coefficient: 0.8318 - iou_metric: 0.7161 - loss: 0.0227 - val_accuracy: 0.9953 - val_dice_coefficient: 0.7758 - val_iou_metric: 0.6364 - val_loss: 0.0109 - learning_rate: 5.0000e-05
# Epoch 30/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9873 - dice_coefficient: 0.8304 - iou_metric: 0.7138 - loss: 0.0203
# Epoch 30: val_loss improved from 0.01085 to 0.01063, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 911ms/step - accuracy: 0.9873 - dice_coefficient: 0.8304 - iou_metric: 0.7138 - loss: 0.0203 - val_accuracy: 0.9954 - val_dice_coefficient: 0.7766 - val_iou_metric: 0.6375 - val_loss: 0.0106 - learning_rate: 5.0000e-05
# Epoch 31/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9883 - dice_coefficient: 0.8381 - iou_metric: 0.7250 - loss: 0.0181
# Epoch 31: val_loss improved from 0.01063 to 0.01037, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 909ms/step - accuracy: 0.9883 - dice_coefficient: 0.8382 - iou_metric: 0.7251 - loss: 0.0181 - val_accuracy: 0.9955 - val_dice_coefficient: 0.7881 - val_iou_metric: 0.6528 - val_loss: 0.0104 - learning_rate: 5.0000e-05
# Epoch 32/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9884 - dice_coefficient: 0.8391 - iou_metric: 0.7274 - loss: 0.0175
# Epoch 32: val_loss did not improve from 0.01037
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 129s 922ms/step - accuracy: 0.9884 - dice_coefficient: 0.8391 - iou_metric: 0.7274 - loss: 0.0176 - val_accuracy: 0.9955 - val_dice_coefficient: 0.7778 - val_iou_metric: 0.6390 - val_loss: 0.0106 - learning_rate: 5.0000e-05
# Epoch 33/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9878 - dice_coefficient: 0.8424 - iou_metric: 0.7320 - loss: 0.0185
# Epoch 33: val_loss did not improve from 0.01037
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 895ms/step - accuracy: 0.9878 - dice_coefficient: 0.8425 - iou_metric: 0.7320 - loss: 0.0185 - val_accuracy: 0.9951 - val_dice_coefficient: 0.7748 - val_iou_metric: 0.6350 - val_loss: 0.0111 - learning_rate: 5.0000e-05
# Epoch 34/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9879 - dice_coefficient: 0.8474 - iou_metric: 0.7392 - loss: 0.0183
# Epoch 34: val_loss improved from 0.01037 to 0.01011, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.9879 - dice_coefficient: 0.8474 - iou_metric: 0.7392 - loss: 0.0183 - val_accuracy: 0.9955 - val_dice_coefficient: 0.7969 - val_iou_metric: 0.6645 - val_loss: 0.0101 - learning_rate: 5.0000e-05
# Epoch 35/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9891 - dice_coefficient: 0.8393 - iou_metric: 0.7269 - loss: 0.0163
# Epoch 35: val_loss did not improve from 0.01011
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 0.9891 - dice_coefficient: 0.8394 - iou_metric: 0.7270 - loss: 0.0163 - val_accuracy: 0.9955 - val_dice_coefficient: 0.7951 - val_iou_metric: 0.6622 - val_loss: 0.0103 - learning_rate: 5.0000e-05
# Epoch 36/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9876 - dice_coefficient: 0.8448 - iou_metric: 0.7358 - loss: 0.0187
# Epoch 36: val_loss did not improve from 0.01011
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 130s 902ms/step - accuracy: 0.9876 - dice_coefficient: 0.8449 - iou_metric: 0.7359 - loss: 0.0187 - val_accuracy: 0.9956 - val_dice_coefficient: 0.7899 - val_iou_metric: 0.6554 - val_loss: 0.0103 - learning_rate: 5.0000e-05
# Epoch 37/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9878 - dice_coefficient: 0.8423 - iou_metric: 0.7322 - loss: 0.0186
# Epoch 37: val_loss did not improve from 0.01011
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 893ms/step - accuracy: 0.9878 - dice_coefficient: 0.8424 - iou_metric: 0.7323 - loss: 0.0186 - val_accuracy: 0.9952 - val_dice_coefficient: 0.7784 - val_iou_metric: 0.6401 - val_loss: 0.0109 - learning_rate: 5.0000e-05
# Epoch 38/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9884 - dice_coefficient: 0.8571 - iou_metric: 0.7533 - loss: 0.0168
# Epoch 38: val_loss did not improve from 0.01011
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 897ms/step - accuracy: 0.9884 - dice_coefficient: 0.8570 - iou_metric: 0.7533 - loss: 0.0169 - val_accuracy: 0.9955 - val_dice_coefficient: 0.7979 - val_iou_metric: 0.6658 - val_loss: 0.0103 - learning_rate: 5.0000e-05
# Epoch 39/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9874 - dice_coefficient: 0.8521 - iou_metric: 0.7462 - loss: 0.0186
# Epoch 39: val_loss did not improve from 0.01011
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 897ms/step - accuracy: 0.9874 - dice_coefficient: 0.8521 - iou_metric: 0.7462 - loss: 0.0186 - val_accuracy: 0.9955 - val_dice_coefficient: 0.8021 - val_iou_metric: 0.6718 - val_loss: 0.0105 - learning_rate: 5.0000e-05
# Epoch 40/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9883 - dice_coefficient: 0.8596 - iou_metric: 0.7574 - loss: 0.0168
# Epoch 40: val_loss improved from 0.01011 to 0.01007, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 910ms/step - accuracy: 0.9883 - dice_coefficient: 0.8595 - iou_metric: 0.7574 - loss: 0.0168 - val_accuracy: 0.9957 - val_dice_coefficient: 0.7958 - val_iou_metric: 0.6633 - val_loss: 0.0101 - learning_rate: 5.0000e-05
# Epoch 41/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9873 - dice_coefficient: 0.8550 - iou_metric: 0.7505 - loss: 0.0184
# Epoch 41: val_loss did not improve from 0.01007
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 129s 924ms/step - accuracy: 0.9873 - dice_coefficient: 0.8549 - iou_metric: 0.7504 - loss: 0.0184 - val_accuracy: 0.9950 - val_dice_coefficient: 0.7762 - val_iou_metric: 0.6373 - val_loss: 0.0116 - learning_rate: 5.0000e-05
# Epoch 42/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9884 - dice_coefficient: 0.8510 - iou_metric: 0.7458 - loss: 0.0169
# Epoch 42: val_loss did not improve from 0.01007
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9884 - dice_coefficient: 0.8510 - iou_metric: 0.7459 - loss: 0.0169 - val_accuracy: 0.9955 - val_dice_coefficient: 0.8087 - val_iou_metric: 0.6812 - val_loss: 0.0103 - learning_rate: 2.5000e-05
# Epoch 43/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9892 - dice_coefficient: 0.8627 - iou_metric: 0.7627 - loss: 0.0148
# Epoch 43: val_loss did not improve from 0.01007
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 893ms/step - accuracy: 0.9892 - dice_coefficient: 0.8628 - iou_metric: 0.7627 - loss: 0.0148 - val_accuracy: 0.9956 - val_dice_coefficient: 0.8046 - val_iou_metric: 0.6761 - val_loss: 0.0103 - learning_rate: 2.5000e-05
# Epoch 44/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9886 - dice_coefficient: 0.8777 - iou_metric: 0.7851 - loss: 0.0153
# Epoch 44: val_loss did not improve from 0.01007
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9886 - dice_coefficient: 0.8776 - iou_metric: 0.7850 - loss: 0.0153 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8094 - val_iou_metric: 0.6823 - val_loss: 0.0101 - learning_rate: 2.5000e-05
# Epoch 45/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9895 - dice_coefficient: 0.8693 - iou_metric: 0.7724 - loss: 0.0139
# Epoch 45: val_loss did not improve from 0.01007
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 895ms/step - accuracy: 0.9895 - dice_coefficient: 0.8694 - iou_metric: 0.7724 - loss: 0.0139 - val_accuracy: 0.9953 - val_dice_coefficient: 0.8071 - val_iou_metric: 0.6790 - val_loss: 0.0111 - learning_rate: 2.5000e-05
# Epoch 46/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9890 - dice_coefficient: 0.8779 - iou_metric: 0.7858 - loss: 0.0145
# Epoch 46: val_loss improved from 0.01007 to 0.01003, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 908ms/step - accuracy: 0.9890 - dice_coefficient: 0.8778 - iou_metric: 0.7858 - loss: 0.0145 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8144 - val_iou_metric: 0.6890 - val_loss: 0.0100 - learning_rate: 2.5000e-05
# Epoch 47/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9893 - dice_coefficient: 0.8770 - iou_metric: 0.7844 - loss: 0.0140
# Epoch 47: val_loss improved from 0.01003 to 0.00999, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 910ms/step - accuracy: 0.9893 - dice_coefficient: 0.8770 - iou_metric: 0.7844 - loss: 0.0140 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8189 - val_iou_metric: 0.6956 - val_loss: 0.0100 - learning_rate: 2.5000e-05
# Epoch 48/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9892 - dice_coefficient: 0.8803 - iou_metric: 0.7890 - loss: 0.0140
# Epoch 48: val_loss improved from 0.00999 to 0.00975, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 911ms/step - accuracy: 0.9892 - dice_coefficient: 0.8802 - iou_metric: 0.7890 - loss: 0.0140 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8154 - val_iou_metric: 0.6903 - val_loss: 0.0098 - learning_rate: 2.5000e-05
# Epoch 49/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9892 - dice_coefficient: 0.8787 - iou_metric: 0.7874 - loss: 0.0140
# Epoch 49: val_loss did not improve from 0.00975
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9892 - dice_coefficient: 0.8787 - iou_metric: 0.7874 - loss: 0.0140 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8176 - val_iou_metric: 0.6937 - val_loss: 0.0099 - learning_rate: 2.5000e-05
# Epoch 50/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9891 - dice_coefficient: 0.8854 - iou_metric: 0.7975 - loss: 0.0139
# Epoch 50: val_loss did not improve from 0.00975
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9891 - dice_coefficient: 0.8854 - iou_metric: 0.7974 - loss: 0.0139 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8194 - val_iou_metric: 0.6964 - val_loss: 0.0101 - learning_rate: 2.5000e-05
# Epoch 51/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9892 - dice_coefficient: 0.8846 - iou_metric: 0.7960 - loss: 0.0137
# Epoch 51: val_loss did not improve from 0.00975
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 892ms/step - accuracy: 0.9892 - dice_coefficient: 0.8846 - iou_metric: 0.7960 - loss: 0.0137 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8205 - val_iou_metric: 0.6979 - val_loss: 0.0099 - learning_rate: 2.5000e-05
# Epoch 52/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9895 - dice_coefficient: 0.8763 - iou_metric: 0.7831 - loss: 0.0136
# Epoch 52: val_loss did not improve from 0.00975
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 895ms/step - accuracy: 0.9895 - dice_coefficient: 0.8763 - iou_metric: 0.7832 - loss: 0.0136 - val_accuracy: 0.9956 - val_dice_coefficient: 0.8210 - val_iou_metric: 0.6987 - val_loss: 0.0105 - learning_rate: 2.5000e-05
# Epoch 53/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9893 - dice_coefficient: 0.8843 - iou_metric: 0.7957 - loss: 0.0137
# Epoch 53: val_loss did not improve from 0.00975
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 895ms/step - accuracy: 0.9893 - dice_coefficient: 0.8843 - iou_metric: 0.7957 - loss: 0.0137 - val_accuracy: 0.9955 - val_dice_coefficient: 0.8102 - val_iou_metric: 0.6836 - val_loss: 0.0106 - learning_rate: 2.5000e-05
# Epoch 54/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9899 - dice_coefficient: 0.8797 - iou_metric: 0.7883 - loss: 0.0131
# Epoch 54: val_loss did not improve from 0.00975
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9899 - dice_coefficient: 0.8798 - iou_metric: 0.7883 - loss: 0.0131 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8235 - val_iou_metric: 0.7021 - val_loss: 0.0100 - learning_rate: 2.5000e-05
# Epoch 55/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9888 - dice_coefficient: 0.8925 - iou_metric: 0.8091 - loss: 0.0139
# Epoch 55: val_loss did not improve from 0.00975
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 892ms/step - accuracy: 0.9888 - dice_coefficient: 0.8924 - iou_metric: 0.8090 - loss: 0.0139 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8202 - val_iou_metric: 0.6977 - val_loss: 0.0100 - learning_rate: 2.5000e-05
# Epoch 56/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9896 - dice_coefficient: 0.8836 - iou_metric: 0.7952 - loss: 0.0132
# Epoch 56: val_loss did not improve from 0.00975
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 899ms/step - accuracy: 0.9896 - dice_coefficient: 0.8836 - iou_metric: 0.7952 - loss: 0.0132 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8252 - val_iou_metric: 0.7047 - val_loss: 0.0101 - learning_rate: 1.2500e-05
# Epoch 57/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9904 - dice_coefficient: 0.8816 - iou_metric: 0.7914 - loss: 0.0119
# Epoch 57: val_loss improved from 0.00975 to 0.00974, saving model to unet_wound_segmentation_best.keras
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 127s 907ms/step - accuracy: 0.9904 - dice_coefficient: 0.8817 - iou_metric: 0.7915 - loss: 0.0119 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8262 - val_iou_metric: 0.7060 - val_loss: 0.0097 - learning_rate: 1.2500e-05
# Epoch 58/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9891 - dice_coefficient: 0.8960 - iou_metric: 0.8146 - loss: 0.0132
# Epoch 58: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 897ms/step - accuracy: 0.9891 - dice_coefficient: 0.8960 - iou_metric: 0.8145 - loss: 0.0132 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8233 - val_iou_metric: 0.7020 - val_loss: 0.0099 - learning_rate: 1.2500e-05
# Epoch 59/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9898 - dice_coefficient: 0.8927 - iou_metric: 0.8093 - loss: 0.0123
# Epoch 59: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9898 - dice_coefficient: 0.8927 - iou_metric: 0.8093 - loss: 0.0123 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8246 - val_iou_metric: 0.7038 - val_loss: 0.0104 - learning_rate: 1.2500e-05
# Epoch 60/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9902 - dice_coefficient: 0.8906 - iou_metric: 0.8063 - loss: 0.0118
# Epoch 60: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9902 - dice_coefficient: 0.8906 - iou_metric: 0.8062 - loss: 0.0118 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8235 - val_iou_metric: 0.7022 - val_loss: 0.0103 - learning_rate: 1.2500e-05
# Epoch 61/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 840ms/step - accuracy: 0.9906 - dice_coefficient: 0.8871 - iou_metric: 0.8002 - loss: 0.0114
# Epoch 61: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 898ms/step - accuracy: 0.9906 - dice_coefficient: 0.8871 - iou_metric: 0.8003 - loss: 0.0114 - val_accuracy: 0.9956 - val_dice_coefficient: 0.8237 - val_iou_metric: 0.7027 - val_loss: 0.0110 - learning_rate: 1.2500e-05
# Epoch 62/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9891 - dice_coefficient: 0.8983 - iou_metric: 0.8184 - loss: 0.0128
# Epoch 62: val_loss did not improve from 0.00974
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 900ms/step - accuracy: 0.9891 - dice_coefficient: 0.8983 - iou_metric: 0.8184 - loss: 0.0128 - val_accuracy: 0.9956 - val_dice_coefficient: 0.8232 - val_iou_metric: 0.7018 - val_loss: 0.0105 - learning_rate: 1.2500e-05
# Epoch 63/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9899 - dice_coefficient: 0.8951 - iou_metric: 0.8129 - loss: 0.0119
# Epoch 63: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 126s 897ms/step - accuracy: 0.9899 - dice_coefficient: 0.8951 - iou_metric: 0.8129 - loss: 0.0119 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8256 - val_iou_metric: 0.7053 - val_loss: 0.0105 - learning_rate: 6.2500e-06
# Epoch 64/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9900 - dice_coefficient: 0.8989 - iou_metric: 0.8191 - loss: 0.0116
# Epoch 64: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 896ms/step - accuracy: 0.9900 - dice_coefficient: 0.8988 - iou_metric: 0.8190 - loss: 0.0116 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8278 - val_iou_metric: 0.7083 - val_loss: 0.0103 - learning_rate: 6.2500e-06
# Epoch 65/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9900 - dice_coefficient: 0.8954 - iou_metric: 0.8133 - loss: 0.0119
# Epoch 65: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 893ms/step - accuracy: 0.9900 - dice_coefficient: 0.8954 - iou_metric: 0.8132 - loss: 0.0119 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8256 - val_iou_metric: 0.7053 - val_loss: 0.0104 - learning_rate: 6.2500e-06
# Epoch 66/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9902 - dice_coefficient: 0.8997 - iou_metric: 0.8205 - loss: 0.0114
# Epoch 66: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 893ms/step - accuracy: 0.9902 - dice_coefficient: 0.8996 - iou_metric: 0.8205 - loss: 0.0114 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8252 - val_iou_metric: 0.7046 - val_loss: 0.0104 - learning_rate: 6.2500e-06
# Epoch 67/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9902 - dice_coefficient: 0.8970 - iou_metric: 0.8159 - loss: 0.0114
# Epoch 67: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9902 - dice_coefficient: 0.8970 - iou_metric: 0.8159 - loss: 0.0114 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8281 - val_iou_metric: 0.7088 - val_loss: 0.0103 - learning_rate: 6.2500e-06
# Epoch 68/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.9902 - dice_coefficient: 0.8937 - iou_metric: 0.8112 - loss: 0.0114
# Epoch 68: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 897ms/step - accuracy: 0.9902 - dice_coefficient: 0.8938 - iou_metric: 0.8112 - loss: 0.0114 - val_accuracy: 0.9957 - val_dice_coefficient: 0.8275 - val_iou_metric: 0.7078 - val_loss: 0.0103 - learning_rate: 6.2500e-06
# Epoch 69/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - accuracy: 0.9904 - dice_coefficient: 0.8917 - iou_metric: 0.8078 - loss: 0.0112
# Epoch 69: val_loss did not improve from 0.00974
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 896ms/step - accuracy: 0.9904 - dice_coefficient: 0.8918 - iou_metric: 0.8079 - loss: 0.0112 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8297 - val_iou_metric: 0.7111 - val_loss: 0.0103 - learning_rate: 6.2500e-06
# Epoch 70/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9904 - dice_coefficient: 0.8910 - iou_metric: 0.8069 - loss: 0.0112
# Epoch 70: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 892ms/step - accuracy: 0.9904 - dice_coefficient: 0.8910 - iou_metric: 0.8070 - loss: 0.0112 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8305 - val_iou_metric: 0.7123 - val_loss: 0.0102 - learning_rate: 3.1250e-06
# Epoch 71/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9903 - dice_coefficient: 0.8988 - iou_metric: 0.8190 - loss: 0.0113
# Epoch 71: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 894ms/step - accuracy: 0.9903 - dice_coefficient: 0.8988 - iou_metric: 0.8190 - loss: 0.0113 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8308 - val_iou_metric: 0.7127 - val_loss: 0.0103 - learning_rate: 3.1250e-06
# Epoch 72/100
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9903 - dice_coefficient: 0.8989 - iou_metric: 0.8197 - loss: 0.0111
# Epoch 72: val_loss did not improve from 0.00974
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 125s 892ms/step - accuracy: 0.9903 - dice_coefficient: 0.8989 - iou_metric: 0.8196 - loss: 0.0111 - val_accuracy: 0.9958 - val_dice_coefficient: 0.8312 - val_iou_metric: 0.7133 - val_loss: 0.0102 - learning_rate: 3.1250e-06
# Epoch 72: early stopping
# Restoring model weights from the end of the best epoch: 57.

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    """
    Plots the training and validation accuracy and loss over epochs.

    Args:
        history (tf.keras.callbacks.History): The history object returned by model.fit.

    Returns:
        None
    """
    # Extract metrics from the history object
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)  # Epochs for the x-axis

    # Plot training and validation accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example usage
plot_training_history(history)

# %%
# Predict on the test dataset
test_predictions = model.predict(test_generator)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 241ms/step

# %%
# Evaluate the model on the test data
test_loss, test_accuracy, test_dice, test_iou = model.evaluate(test_generator, verbose=1)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 223ms/step - accuracy: 0.9959 - dice_coefficient: 0.8191 - iou_metric: 0.6950 - loss: 0.0095
# Test Accuracy: 0.9958

# %%
import matplotlib.pyplot as plt

def plot_training_history(history, test_accuracy=None):
    """
    Plots the training and validation accuracy and loss over epochs.
    Optionally, adds a horizontal line for Test Accuracy.

    Args:
        history (tf.keras.callbacks.History): The history object returned by model.fit.
        test_accuracy (float): Test accuracy to display on the plot (optional).

    Returns:
        None
    """
    # Extract metrics from the history object
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)  # Epochs for the x-axis

    # Plot training and validation accuracy
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training Accuracy')
    plt.plot(epochs, val_acc, 'ro-', label='Validation Accuracy')
    
    # Add Test Accuracy as a horizontal line
    if test_accuracy is not None:
        plt.axhline(y=test_accuracy, color='g', linestyle='--', label=f'Test Accuracy: {test_accuracy:.4f}')
    
    plt.title('Training, Validation, and Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training Loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Evaluate the model on the test data
test_loss, test_accuracy, test_dice, test_iou = model.evaluate(test_generator, verbose=1)

# Print the test accuracy
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Dice Coefficient: {test_dice:.4f}")
print(f"Test IoU: {test_iou:.4f}")

# Plot training history with Test Accuracy
plot_training_history(history, test_accuracy)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - accuracy: 0.9959 - dice_coefficient: 0.8191 - iou_metric: 0.6950 - loss: 0.0095
# Test Accuracy: 0.9958
# Test Dice Coefficient: 0.8262
# Test IoU: 0.7060

# %%
# Save the model in .h5 format
model.save('unet_wound_segmentation_model.h5')

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# 1. Get true masks and predictions (same as before)
def get_true_and_predicted_masks(generator, model):
    true_masks = []
    predicted_masks = []
    
    for i in tqdm(range(len(generator))):
        batch_images, batch_masks = generator[i]
        batch_preds = model.predict(batch_images, verbose=0)
        true_masks.append(batch_masks)
        predicted_masks.append(batch_preds)
    
    return np.concatenate(true_masks), np.concatenate(predicted_masks)

true_masks, pred_masks = get_true_and_predicted_masks(test_generator, model)

# 2. Threshold and convert to integers
threshold = 0.5
binary_preds = (pred_masks > threshold).astype(np.int8)  # Convert to integers
binary_true = (true_masks > threshold).astype(np.int8)   # Ensure ground truth is also binary

# 3. Flatten arrays
y_true = binary_true.flatten()
y_pred = binary_preds.flatten()

# 4. Calculate metrics
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

# 5. Get other metrics from model evaluation
test_loss, test_acc, test_dice, test_iou = model.evaluate(test_generator, verbose=0)

# 6. Create report
report = {
    "Test Accuracy": f"{test_acc:.4f}",
    "Test Dice Coefficient": f"{test_dice:.4f}",
    "Test IoU": f"{test_iou:.4f}",
    "Precision": f"{precision:.4f}",
    "Recall": f"{recall:.4f}",
    "F1 Score": f"{f1:.4f}"
}

# 7. Print formatted report
print("Model Performance Report:")
print("="*40)
for metric, value in report.items():
    print(f"{metric:20}: {value}")
print("="*40)
# Out:
# 100%|██████████| 35/35 [00:15<00:00,  2.19it/s]
# Model Performance Report:
# ========================================
# Test Accuracy       : 0.9958
# Test Dice Coefficient: 0.8262
# Test IoU            : 0.7060
# Precision           : 0.8679
# Recall              : 0.8760
# F1 Score            : 0.8719
# ========================================

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images/fusc_0021.png'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images/fusc_0024.png'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-segmentation-images/data_wound_seg/test_images/fusc_0030.png'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-classification/Wound_dataset copy/Abrasions/abrasions (10).jpg'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-classification/Wound_dataset copy/Pressure Wounds/mirrored_sloughy-pressure-ulcer-0038.jpg'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-classification/Wound_dataset copy/Burns/burns (23).jpg'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-classification/Wound_dataset copy/Surgical Wounds/109_0.jpg'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-classification/Wound_dataset copy/Surgical Wounds/100_0.jpg'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-classification/Wound_dataset copy/Venous Wounds/108_1.jpg'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# Load the trained model
model = load_model('unet_wound_segmentation_model.h5', custom_objects={'dice_coefficient': dice_coefficient, 'iou_metric': iou_metric})

def preprocess_image(image_path, target_size=(256, 256)):
    """
    Load and preprocess an image for prediction.

    Args:
        image_path (str): Path to the image file.
        target_size (tuple): Target size for resizing the image. Default is (256, 256).

    Returns:
        np.array: Preprocessed image.
    """
    # Load the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB
    image = cv2.resize(image, target_size)  # Resize to target size
    image = image / 255.0  # Normalize to [0, 1]
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

def display_prediction(image_path, model):
    """
    Display the original image and its prediction (segmentation mask).

    Args:
        image_path (str): Path to the image file.
        model (tf.keras.Model): Trained model for prediction.

    Returns:
        None
    """
    # Preprocess the image
    image = preprocess_image(image_path)

    # Generate prediction
    prediction = model.predict(image)
    prediction_mask = (prediction.squeeze() > 0.5).astype(np.uint8)  # Apply threshold (0.5)

    # Load the original image for display
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)

    # Display the original image and the prediction
    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(original_image)
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(prediction_mask, cmap='gray')
    plt.title('Prediction Mask')
    plt.axis('off')

    plt.tight_layout()
    plt.show()

# Test the model on a new image
test_image_path = '/kaggle/input/wound-classification/Wound_dataset copy/Venous Wounds/110_0.jpg'  
display_prediction(test_image_path, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step

# %%
def generate_confusion_matrix(model, test_generator, threshold=0.5):
    """
    Generates a confusion matrix for segmentation results.
    
    Args:
        model: Trained model
        test_generator: Test data generator
        threshold: Threshold for binary classification of pixels
    
    Returns:
        cm: Confusion matrix as [[TN, FP], [FN, TP]]
    """
    # Initialize counters
    TN, FP, FN, TP = 0, 0, 0, 0

    # Process all test data
    for i in tqdm(range(len(test_generator))):
        batch_images, batch_masks = test_generator[i]
        pred_masks = model.predict(batch_images, verbose=0)
        
        # Threshold predictions and flatten
        y_true = batch_masks.flatten() > 0.5
        y_pred = pred_masks.flatten() > threshold

        # Update confusion matrix counts
        TN += np.sum((y_pred == False) & (y_true == False))
        FP += np.sum((y_pred == True) & (y_true == False))
        FN += np.sum((y_pred == False) & (y_true == True))
        TP += np.sum((y_pred == True) & (y_true == True))

    return np.array([[TN, FP], [FN, TP]])

def plot_confusion_matrix(cm, class_names=['Background', 'Wound']):
    """
    Plots a confusion matrix using seaborn heatmap.
    
    Args:
        cm: Confusion matrix array
        class_names: List of class names
    """
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Calculate metrics
    accuracy = (cm[0,0] + cm[1,1]) / cm.sum()
    precision = cm[1,1] / (cm[1,1] + cm[0,1])
    recall = cm[1,1] / (cm[1,1] + cm[1,0])
    dice = (2 * cm[1,1]) / (2 * cm[1,1] + cm[0,1] + cm[1,0])

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall/Sensitivity: {recall:.4f}")
    print(f"Dice Coefficient: {dice:.4f}")

# Generate and plot confusion matrix
cm = generate_confusion_matrix(model, test_generator)
plot_confusion_matrix(cm)
# Out:
# 100%|██████████| 35/35 [00:18<00:00,  1.87it/s]
# Accuracy: 0.9965
# Precision: 0.8679
# Recall/Sensitivity: 0.8760
# Dice Coefficient: 0.8719
